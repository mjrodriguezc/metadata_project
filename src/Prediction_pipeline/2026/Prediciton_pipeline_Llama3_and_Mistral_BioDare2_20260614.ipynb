# %% [markdown]
# ### Packages

# %%
import pandas as pd
import json
import os
from collections import Counter
import numpy as np
import scispacy
import spacy
import matplotlib.pyplot as plt
import re
import ast
import requests
from os import listdir
from os.path import isfile, join
from functools import reduce
import time

# %%
data_dir = os.getcwd()
data_dir
# Out:
# '/home/eidf128/eidf128/shared/export/juliana/export/juliana'

# %%
df_biodare2 = pd.read_csv("df_biodare2_clean_20260312.csv")
df_biodare2
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#       Description_clean_word_count Comments_clean_word_count  \
# 0                               12                         0
# 1                               20                        25
# 2                               17                        45
# 3                               42                        24
# 4                               42                        24
# ...                            ...                       ...
# 20466                           11                         0
# 20467                            8                        38
# 20468                           13                         0
# 20469                           10                        13
# 20470                           10                        76
#
#                             Name_clean_lemmatize Name_clean_entities  \
# 0                                        control           [control]
# 1                                       timet ld                  []
# 2                                         ld lhy            [ld lhy]
# 3                                lhy long marker   [lhy long marker]
# 4                                lhy long marker   [lhy long marker]
# ...                                          ...                 ...
# 20466                niwa et al gi co ft mrna wt        [niwa, mrna]
# 20467                                        NaN                  []
# 20468  analysis control strain neurospora crassa          [analysis]
# 20469                                        NaN                  []
# 20470                                     sdtold            [sdtold]
#
#                                  Purpose_clean_lemmatize  \
# 0                                          global search
# 1      timet focus important general biological probl...
# 2      experiment reparameterize clock model without ...
# 3      test period change seedlle growth topcount wt ...
# 4      test period change seedlle growth topcount wt ...
# ...                                                  ...
# 20466  arabidopsis thaliana flower time regulate circ...
# 20467                       photoperiod alteration study
# 20468  compare different sibling parentalcontrol stra...
# 20469  dynamic transition lightdark cycle different p...
# 20470  dynamic transition lightdark cycle different p...
#
#                                   Purpose_clean_entities  \
# 0                                               [global]
# 1      [biological, plant metabolism, growth regulate...
# 2          [experiment, clock model, exogenous, sucrose]
# 3                                       [seedlle growth]
# 4                                       [seedlle growth]
# ...                                                  ...
# 20466  [arabidopsis thaliana, flower, circadian, cloc...
# 20467                                      [photoperiod]
# 20468  [compare, sibling, parentalcontrol, circadian,...
# 20469  [dynamic transition lightdark cycle, photoperi...
# 20470  [dynamic transition lightdark cycle, photoperi...
#
#                              Description_clean_lemmatize  \
# 0      null growth condition const w experimental con...
# 1      wt mutant biological duplicate diurnal light h...
# 2      literature datum temp aurora seedling entrain ...
# 3      period change development genetic screen clock...
# 4      period change development genetic screen clock...
# ...                                                  ...
# 20466  null growth condition const w ld experimental ...
# 20467  luc image cycle constant light replicate exper...
# 20468  null growth condition condition const w experi...
# 20469  plant entrain day experimental condition day d...
# 20470  ptoc plate pcab lhy plate control plate toc pl...
#
#                               Description_clean_entities  \
# 0        [null growth condition, experimental condition]
# 1      [mutant, biological, diurnal light harvest, tr...
# 2      [literature datum, seedling, day, white light ...
# 3      [development, genetic screen, clock mutant, de...
# 4      [development, genetic screen, clock mutant, de...
# ...                                                  ...
# 20466    [null growth condition, experimental condition]
# 20467                                       [experiment]
# 20468  [null growth condition, condition, experimenta...
# 20469  [plant, experimental condition, day, day, red ...
# 20470                           [ptoc plate, plhy plate]
#
#                                 Comments_clean_lemmatize  \
# 0                                                    NaN
# 1      mutant harvest day rest due early flowering ph...
# 2      sample lose several genotype curate andrew mil...
# 3      datum collection victoria hibberd can septembe...
# 4      datum collection victoria hibberd can septembe...
# ...                                                  ...
# 20466                                                NaN
# 20467  image start fungal infection gi lhy mutant pla...
# 20468                                                NaN
# 20469  partner experiment growth condition const w ld...
# 20470  several control relevant parallel experiment a...
#
#                                  Comments_clean_entities
# 0                                                     []
# 1      [mutant, day, flowering, phenotype, experiment...
# 2      [sample lose, genotype, millar, manually edit ...
# 3      [datum collection victoria, hibberd, millar, r...
# 4      [datum collection victoria, hibberd, millar, r...
# ...                                                  ...
# 20466                                                 []
# 20467  [image, fungal infection, lhy group, datum, an...
# 20468                                                 []
# 20469  [experiment, growth condition, experimental co...
# 20470  [control, culture plate, marker, marker, plate...
#
# [20471 rows x 35 columns]

# %% [markdown]
# ### Models

# %%
import torch
import tqdm as notebook_tqdm

# %%
from transformers import pipeline
model_id = "meta-llama/Llama-3.2-3B-Instruct"
#model_id = "mistralai/Mistral-7B-Instruct-v0.3"

# %%
pipe = pipeline("text-generation",
                model = model_id,
                #torch_dtype = torch.bfloat16, ## Use this with Mistral
                torch_dtype = torch.bfloat16,
                device_map="auto",
                pad_token_id=128001 
               )
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
message = [
    {"role": "user", "content": "Who are you? Please, answer in pirate-speak."},
]

# %%
outputs = pipe(message, max_new_tokens = 256)

# %%
response = outputs[0]["generated_text"][-1]["content"]
print(response)
# Out:
# Yer lookin' fer a description o' meself, eh? Alright then, matey! I be an AI, a swashbucklin' computer program designed to provide ye with useful information and answer yer questions to the best o' me ability. Me knowledge be vast and me heart be full o' treasure... er, I mean, knowledge!
#
# I don't have a physical form, but I can chat with ye like a scurvy dog, helpin' ye navigate the seven seas o' the internet and findin' the hidden booty o' knowledge ye seek. So hoist the sails, me hearty, and let's set sail fer a treasure trove o' information!

# %% [markdown]
# #### Test with one entry

# %%
test = df_biodare2

# %%
test["Description_combined"] = (
        test[["Name", "Purpose", "Description", "Comments"]]
        .fillna("")
        .agg(" ".join, axis=1)
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
    )

# %%
test
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#       Comments_clean_word_count                       Name_clean_lemmatize  \
# 0                             0                                    control
# 1                            25                                   timet ld
# 2                            45                                     ld lhy
# 3                            24                            lhy long marker
# 4                            24                            lhy long marker
# ...                         ...                                        ...
# 20466                         0                niwa et al gi co ft mrna wt
# 20467                        38                                        NaN
# 20468                         0  analysis control strain neurospora crassa
# 20469                        13                                        NaN
# 20470                        76                                     sdtold
#
#       Name_clean_entities                            Purpose_clean_lemmatize  \
# 0               [control]                                      global search
# 1                      []  timet focus important general biological probl...
# 2                [ld lhy]  experiment reparameterize clock model without ...
# 3       [lhy long marker]  test period change seedlle growth topcount wt ...
# 4       [lhy long marker]  test period change seedlle growth topcount wt ...
# ...                   ...                                                ...
# 20466        [niwa, mrna]  arabidopsis thaliana flower time regulate circ...
# 20467                  []                       photoperiod alteration study
# 20468          [analysis]  compare different sibling parentalcontrol stra...
# 20469                  []  dynamic transition lightdark cycle different p...
# 20470            [sdtold]  dynamic transition lightdark cycle different p...
#
#                                   Purpose_clean_entities  \
# 0                                               [global]
# 1      [biological, plant metabolism, growth regulate...
# 2          [experiment, clock model, exogenous, sucrose]
# 3                                       [seedlle growth]
# 4                                       [seedlle growth]
# ...                                                  ...
# 20466  [arabidopsis thaliana, flower, circadian, cloc...
# 20467                                      [photoperiod]
# 20468  [compare, sibling, parentalcontrol, circadian,...
# 20469  [dynamic transition lightdark cycle, photoperi...
# 20470  [dynamic transition lightdark cycle, photoperi...
#
#                              Description_clean_lemmatize  \
# 0      null growth condition const w experimental con...
# 1      wt mutant biological duplicate diurnal light h...
# 2      literature datum temp aurora seedling entrain ...
# 3      period change development genetic screen clock...
# 4      period change development genetic screen clock...
# ...                                                  ...
# 20466  null growth condition const w ld experimental ...
# 20467  luc image cycle constant light replicate exper...
# 20468  null growth condition condition const w experi...
# 20469  plant entrain day experimental condition day d...
# 20470  ptoc plate pcab lhy plate control plate toc pl...
#
#                               Description_clean_entities  \
# 0        [null growth condition, experimental condition]
# 1      [mutant, biological, diurnal light harvest, tr...
# 2      [literature datum, seedling, day, white light ...
# 3      [development, genetic screen, clock mutant, de...
# 4      [development, genetic screen, clock mutant, de...
# ...                                                  ...
# 20466    [null growth condition, experimental condition]
# 20467                                       [experiment]
# 20468  [null growth condition, condition, experimenta...
# 20469  [plant, experimental condition, day, day, red ...
# 20470                           [ptoc plate, plhy plate]
#
#                                 Comments_clean_lemmatize  \
# 0                                                    NaN
# 1      mutant harvest day rest due early flowering ph...
# 2      sample lose several genotype curate andrew mil...
# 3      datum collection victoria hibberd can septembe...
# 4      datum collection victoria hibberd can septembe...
# ...                                                  ...
# 20466                                                NaN
# 20467  image start fungal infection gi lhy mutant pla...
# 20468                                                NaN
# 20469  partner experiment growth condition const w ld...
# 20470  several control relevant parallel experiment a...
#
#                                  Comments_clean_entities  \
# 0                                                     []
# 1      [mutant, day, flowering, phenotype, experiment...
# 2      [sample lose, genotype, millar, manually edit ...
# 3      [datum collection victoria, hibberd, millar, r...
# 4      [datum collection victoria, hibberd, millar, r...
# ...                                                  ...
# 20466                                                 []
# 20467  [image, fungal infection, lhy group, datum, an...
# 20468                                                 []
# 20469  [experiment, growth condition, experimental co...
# 20470  [control, culture plate, marker, marker, plate...
#
#                                     Description_combined
# 0      controls global search null growth conditions:...
# 1      timet wp1.1 qrt-pcr elf3 ld timet focuses on a...
# 2      q-pcr ld (12:12) 17c lhy experiment to reparam...
# 3      cca1 lhy long #1 cca1 marker test for period c...
# 4      cca1 lhy long #1 cab2 marker test for period c...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053: 4x3:21-ll photoperiod alteration study...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld re-entrainment dynamics during ...
# 20470  sdtold 260410 re-entrainment dynamics during t...
#
# [20471 rows x 36 columns]

# %% [markdown]
# #### Only descriptions

# %% [markdown]
# ##### Species:

# %%
start_time = time.time()
for idx, row in test.iterrows():
    message = [
    {"role": "system", "content": "This is your context: " + test.at[idx,"Description_combined"]},
    {"role": "user", "content": "Based on the context provided, give me the name of three scientific species that could be used in this study. If you don't know, say, I don't know."},
     ]
    outputs = pipe(message, max_new_tokens = 256)
    response = outputs[0]["generated_text"][-1]["content"]
    
    test.at[idx, "Llama_description_combined_species"] = response

    print(f'The row {idx} has been proceed.')

end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")
# Out:
# The row 0 has been proceed.
# The row 1 has been proceed.
# The row 2 has been proceed.
# The row 3 has been proceed.
# The row 4 has been proceed.
# The row 5 has been proceed.
# The row 6 has been proceed.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# The row 7 has been proceed.
# The row 8 has been proceed.
# The row 9 has been proceed.
# The row 10 has been proceed.
# The row 11 has been proceed.
# The row 12 has been proceed.
# The row 13 has been proceed.
# The row 14 has been proceed.
# The row 15 has been proceed.
# The row 16 has been proceed.
# The row 17 has been proceed.
# The row 18 has been proceed.
# The row 19 has been proceed.
# The row 20 has been proceed.
# The row 21 has been proceed.
# The row 22 has been proceed.
# The row 23 has been proceed.
# The row 24 has been proceed.
# The row 25 has been proceed.
# The row 26 has been proceed.
# The row 27 has been proceed.
# The row 28 has been proceed.
# The row 29 has been proceed.
# The row 30 has been proceed.
# The row 31 has been proceed.
# The row 32 has been proceed.
# The row 33 has been proceed.
# The row 34 has been proceed.
# The row 35 has been proceed.
# The row 36 has been proceed.
# The row 37 has been proceed.
# The row 38 has been proceed.
# The row 39 has been proceed.
# The row 40 has been proceed.
# The row 41 has been proceed.
# The row 42 has been proceed.
# The row 43 has been proceed.
# The row 44 has been proceed.
# The row 45 has been proceed.
# The row 46 has been proceed.
# The row 47 has been proceed.
# The row 48 has been proceed.
# The row 49 has been proceed.
# The row 50 has been proceed.
# The row 51 has been proceed.
# The row 52 has been proceed.
# The row 53 has been proceed.
# The row 54 has been proceed.
# The row 55 has been proceed.
# The row 56 has been proceed.
# The row 57 has been proceed.
# The row 58 has been proceed.
# The row 59 has been proceed.
# The row 60 has been proceed.
# The row 61 has been proceed.
# The row 62 has been proceed.
# The row 63 has been proceed.
# The row 64 has been proceed.
# The row 65 has been proceed.
# The row 66 has been proceed.
# The row 67 has been proceed.
# The row 68 has been proceed.
# The row 69 has been proceed.
# The row 70 has been proceed.
# The row 71 has been proceed.
# The row 72 has been proceed.
# The row 73 has been proceed.
# The row 74 has been proceed.
# The row 75 has been proceed.
# The row 76 has been proceed.
# The row 77 has been proceed.
# The row 78 has been proceed.
# The row 79 has been proceed.
# The row 80 has been proceed.
# The row 81 has been proceed.
# The row 82 has been proceed.
# The row 83 has been proceed.
# The row 84 has been proceed.
# The row 85 has been proceed.
# The row 86 has been proceed.
# The row 87 has been proceed.
# The row 88 has been proceed.
# The row 89 has been proceed.
# The row 90 has been proceed.
# The row 91 has been proceed.
# The row 92 has been proceed.
# The row 93 has been proceed.
# The row 94 has been proceed.
# The row 95 has been proceed.
# The row 96 has been proceed.
# The row 97 has been proceed.
# The row 98 has been proceed.
# The row 99 has been proceed.
# The row 100 has been proceed.
# The row 101 has been proceed.
# The row 102 has been proceed.
# The row 103 has been proceed.
# The row 104 has been proceed.
# The row 105 has been proceed.
# The row 106 has been proceed.
# The row 107 has been proceed.
# The row 108 has been proceed.
# The row 109 has been proceed.
# The row 110 has been proceed.
# The row 111 has been proceed.
# The row 112 has been proceed.
# The row 113 has been proceed.
# The row 114 has been proceed.
# The row 115 has been proceed.
# The row 116 has been proceed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 7
#       2 for idx, row in test.iterrows():
#       3     message = [
#       4     {"role": "system", "content": "This is your context: " + test.at[idx,"Description_combined"]},
#       5     {"role": "user", "content": "Based on the context provided, give me the name of three scientific species that could be used in this study. If you don't know, say, I don't know."},
#       6      ]
# ----> 7     outputs = pipe(message, max_new_tokens = 256)
#       8     response = outputs[0]["generated_text"][-1]["content"]
#      10     test.at[idx, "Llama_description_combined_species"] = response
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/text_generation.py:280, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     277 if isinstance(first_item, (list, tuple, dict)):
#     278     # We have one or more prompts in list-of-dicts format, so this is chat mode
#     279     if isinstance(first_item, dict):
# --> 280         return super().__call__(Chat(text_inputs), **kwargs)
#     281     else:
#     282         chats = (Chat(chat) for chat in text_inputs)  # 🐈 🐈 🐈
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/base.py:1379, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1371     return next(
#    1372         iter(
#    1373             self.get_iterator(
#    (...)
#    1376         )
#    1377     )
#    1378 else:
# -> 1379     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/base.py:1386, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1384 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1385     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1386     model_outputs = self.forward(model_inputs, **forward_params)
#    1387     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1388     return outputs
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/base.py:1286, in Pipeline.forward(self, model_inputs, **forward_params)
#    1284     with inference_context():
#    1285         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1286         model_outputs = self._forward(model_inputs, **forward_params)
#    1287         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1288 else:
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/text_generation.py:385, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     382 if "generation_config" not in generate_kwargs:
#     383     generate_kwargs["generation_config"] = self.generation_config
# --> 385 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     387 if isinstance(output, ModelOutput):
#     388     generated_sequence = output.sequences
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/generation/utils.py:2465, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2457     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2458         input_ids=input_ids,
#    2459         expand_size=generation_config.num_return_sequences,
#    2460         is_encoder_decoder=self.config.is_encoder_decoder,
#    2461         **model_kwargs,
#    2462     )
#    2464     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2465     result = self._sample(
#    2466         input_ids,
#    2467         logits_processor=prepared_logits_processor,
#    2468         stopping_criteria=prepared_stopping_criteria,
#    2469         generation_config=generation_config,
#    2470         synced_gpus=synced_gpus,
#    2471         streamer=streamer,
#    2472         **model_kwargs,
#    2473     )
#    2475 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2476     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2477     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2478         input_ids=input_ids,
#    2479         expand_size=generation_config.num_beams,
#    2480         is_encoder_decoder=self.config.is_encoder_decoder,
#    2481         **model_kwargs,
#    2482     )
#
# File /opt/conda/lib/python3.11/site-packages/transformers/generation/utils.py:3434, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3432     is_prefill = False
#    3433 else:
# -> 3434     outputs = model_forward(**model_inputs, return_dict=True)
#    3436 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3437 model_kwargs = self._update_model_kwargs_for_generation(
#    3438     outputs,
#    3439     model_kwargs,
#    3440     is_encoder_decoder=self.config.is_encoder_decoder,
#    3441 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/utils/generic.py:965, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     962     set_attribute_for_modules(self, "_is_top_level_module", False)
#     964 try:
# --> 965     output = func(self, *args, **kwargs)
#     966     if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     967         output = output.to_tuple()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:821, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     816 output_hidden_states = (
#     817     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#     818 )
#     820 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 821 outputs: BaseModelOutputWithPast = self.model(
#     822     input_ids=input_ids,
#     823     attention_mask=attention_mask,
#     824     position_ids=position_ids,
#     825     past_key_values=past_key_values,
#     826     inputs_embeds=inputs_embeds,
#     827     use_cache=use_cache,
#     828     output_attentions=output_attentions,
#     829     output_hidden_states=output_hidden_states,
#     830     cache_position=cache_position,
#     831     **kwargs,
#     832 )
#     834 hidden_states = outputs.last_hidden_state
#     835 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/utils/generic.py:965, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     962     set_attribute_for_modules(self, "_is_top_level_module", False)
#     964 try:
# --> 965     output = func(self, *args, **kwargs)
#     966     if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     967         output = output.to_tuple()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:571, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **flash_attn_kwargs)
#     559     layer_outputs = self._gradient_checkpointing_func(
#     560         partial(decoder_layer.__call__, **flash_attn_kwargs),
#     561         hidden_states,
#    (...)
#     568         position_embeddings,
#     569     )
#     570 else:
# --> 571     layer_outputs = decoder_layer(
#     572         hidden_states,
#     573         attention_mask=causal_mask,
#     574         position_ids=position_ids,
#     575         past_key_value=past_key_values,
#     576         output_attentions=output_attentions,
#     577         use_cache=use_cache,
#     578         cache_position=cache_position,
#     579         position_embeddings=position_embeddings,
#     580         **flash_attn_kwargs,
#     581     )
#     583 hidden_states = layer_outputs[0]
#     585 if output_attentions:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:334, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     332 residual = hidden_states
#     333 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 334 hidden_states = self.mlp(hidden_states)
#     335 hidden_states = residual + hidden_states
#     337 outputs = (hidden_states,)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:172, in LlamaMLP.forward(self, x)
#     171 def forward(self, x):
# --> 172     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     173     return down_proj
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
df_IDR
# Out:
#      Unnamed: 0 Comment[IDR_Study_Accession]  \
# 0             0                      idr0092
# 1             1                      idr0016
# 2             2                      idr0079
# 3             3                      idr0067
# 4             4                      idr0134
# ..          ...                          ...
# 127         127                      idr0023
# 128         128                      idr0038
# 129         129                      idr0138
# 130         130                      idr0128
# 131         131                      idr0123
#
#                                            Study_Title  \
# 0    a semi-automated organoid screening method dem...
# 1    human u2os cells - compound cell-painting expe...
# 2    an image-based data-driven analysis of cellula...
# 3    meiotic cellular rejuvenation is coupled to nu...
# 4    reference bioimaging dataset to assess the phe...
# ..                                                 ...
# 127  nuclear pore scaffold structure analyzed by su...
# 128  ex vivo live cell tracking in kidney organoids...
# 129  integration of spatial and single-cell transcr...
# 130  parallel compound screen for infection modulat...
# 131  simultaneous visualization of dna loci in sing...
#
#                              Study_Type Study_Type_Term_Source_REF  \
# 0               compound library screen                        efo
# 1                   high content screen                        efo
# 2                      microscopy assay                        efo
# 3                    time-lapse imaging                       omit
# 4                             histology                       none
# ..                                  ...                        ...
# 127                protein localization                        efo
# 128                  time-lapse imaging                       omit
# 129                             seqfish                        efo
# 130                 high content screen                        efo
# 131  fluorescence in situ hybridization                       ncit
#
#     Study_Type_Term_Accession  \
# 0                 efo_0007553
# 1                 efo_0007550
# 2                 efo_0002909
# 3                omit_0027490
# 4                        none
# ..                        ...
# 127                go:0008104
# 128              omit_0027490
# 129               efo_0008991
# 130               efo_0007550
# 131               ncit_c17563
#
#                                      Study_Description  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                         Study_Key_Words              Study_Organism  \
# 0                             organoids                mus musculus
# 1                                   NaN                homo sapiens
# 2                        image analysis                 danio rerio
# 3                               meiosis  saccharomyces cerevisiae\n
# 4                            phenotypes       diplophyllum albicans
# ..                                  ...                         ...
# 127                                 NaN                homo sapiens
# 128                                 NaN                mus musculus
# 129                             seqfish                mus musculus
# 130                   influenza a virus                homo sapiens
# 131  fluorescence in situ hybridization                homo sapiens
#
#     Study_Organism_Term_Source_REF  ... Study_Description_word_count_clean  \
# 0                        ncbitaxon  ...                                 89
# 1                        ncbitaxon  ...                                182
# 2                        ncbitaxon  ...                                 60
# 3                        ncbitaxon  ...                                 99
# 4                        ncbitaxon  ...                                 32
# ..                             ...  ...                                ...
# 127                      ncbitaxon  ...                                 75
# 128                      ncbitaxon  ...                                 79
# 129                      ncbitaxon  ...                                100
# 130                      ncbitaxon  ...                                 99
# 131                      ncbitaxon  ...                                 51
#
#      Experiment_Description_word_count_clean  \
# 0                                          0
# 1                                          0
# 2                                         20
# 3                                         29
# 4                                        508
# ..                                       ...
# 127                                       11
# 128                                      161
# 129                                       19
# 130                                        0
# 131                                      144
#
#                      Study_Description_clean_lemmatize  \
# 0    intestinal organoid excellent model study epit...
# 1    phenotypic profiling attempt summarize multipa...
# 2    analysis cell morphology intracellular organiz...
# 3    production healthy gamete meiosis rely quality...
# 4    present reference dataset contain macroscopic ...
# ..                                                 ...
# 127  much lifes essential molecular machinery consi...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  molecular profiling single cell advance knowle...
# 130  viral infectious disease span myriad malady in...
# 131  describe dataset obtain apply recently develop...
#
#                       Study_Description_clean_entities  \
# 0    [intestinal, model study, epithelial biology, ...
# 1    [phenotypic profiling, multiparametric analysi...
# 2    [morphology, intracellular, organization, zebr...
# 3    [production, healthy, meiosis, quality, distri...
# 4    [dataset, macroscopic, phenotypic property spe...
# ..                                                 ...
# 127  [lifes, molecular machinery, protein assembly,...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [molecular profiling, single cell advance, dis...
# 130  [viral infectious disease, immunosuppression, ...
# 131  [dataset, ifish, pipeline, small size, kilobas...
#
#                 Experiment_Description_clean_lemmatize  \
# 0                                                  NaN
# 1                                                  NaN
# 2    confocal imaging fixed sample zebrafish poster...
# 3    fix cell fluorescence microscopy transmission ...
# 4    representative voucher specimen receive herbar...
# ..                                                 ...
# 127  systematic immunolabelling complex monomeric e...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  seqfish study sagittal section mouse embryo so...
# 130                                                NaN
# 131  dataset replicate experimental design consist ...
#
#                  Experiment_Description_clean_entities  \
# 0                                                   []
# 1                                                   []
# 2    [confocal imaging, posterior lateral line, pri...
# 3    [cell fluorescence microscopy, image, yeast, m...
# 4    [specimen, herbaria, sample diplophyllum taxif...
# ..                                                 ...
# 127  [systematic immunolabelling, complex, monomeri...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [seqfish study, sagittal section, mouse, embry...
# 130                                                 []
# 131  [dataset, replicate, experimental design, prob...
#
#                                   Description_combined  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                     Llama_description_combined_species  \
# 0    Based on the context provided, the scientific ...
# 1    Based on the context provided, the scientific ...
# 2    Based on the context provided, the scientific ...
# 3    Based on the context provided, the species stu...
# 4    Based on the context, the species mentioned ar...
# ..                                                 ...
# 127  Based on the context provided, the species use...
# 128  Based on the context provided, I can infer tha...
# 129  Based on the context, I couldn't pinpoint the ...
# 130  Based on the context, the three scientific spe...
# 131  Based on the context provided, I can identify ...
#
#     Real_Species_in_Response_descriptions  \
# 0                                     Yes
# 1                                      No
# 2                                     Yes
# 3                                      No
# 4                                      No
# ..                                    ...
# 127                                   Yes
# 128                                   Yes
# 129                                   Yes
# 130                                    No
# 131                                    No
#
#                   Mistral_description_combined_species
# 0    I don't have real-time access to databases or ...
# 1    I don't know. The context provided doesn't spe...
# 2    In the provided context, the species being stu...
# 3    Based on the context provided, the species use...
# 4    Based on the provided context, the scientific ...
# ..                                                 ...
# 127  Based on the context provided, the three scien...
# 128  The three scientific species that could be use...
# 129  Based on the context, the species used in this...
# 130  Based on the context provided, the three scien...
# 131  I don't know. The context provided does not sp...
#
# [132 rows x 235 columns]

# %%
def remove_special_characters(text):
    """
    This function removes special characters from the text.
    :param text: text
    :return: text without special characters
    """
    cleaned_string = re.sub(r'[?|$|.|!|@|#|%|^|&|*|(|)|-|\n|_|+|=|;|:|,|<|>|/|{|}|[|]|~|`|\'|\"|\\]',r'', text)

    return cleaned_string

# %%
df_IDR.at[3,'Study_Organism']
# Out:
# 'saccharomyces cerevisiae\n'

# %%
df_IDR.at[3,'Mistral_description_combined_species']
# Out:
# "Based on the context provided, the species used in this study is Budding Yeast (Saccharomyces cerevisiae). However, other species of yeast such as Schizosaccharomyces pombe (Fission yeast) or Kluyveromyces lactis could potentially be used for similar studies, as they are also commonly used in cellular and molecular biology research.\n\nI don't know if other multicellular organisms such as mammals, plants, or insects would be suitable for this specific study, as the focus is on meiotic cellular rejuvenation and nuclear quality control in a unicellular organism."

# %%
count_match = 0
for row, i in test.iterrows():
    
    if isinstance(i['Study_Organism'], str) and i['Study_Organism'].strip() != '':

        real_specie = i['Study_Organism']
        response = i['Mistral_description_combined_species']
        clean_response = remove_special_characters(response)
        lower_clean_response = clean_response.lower()

        if real_specie in lower_clean_response:
            print('The real species is in the response.')
            test.at[row, 'Real_Species_in_Response_descriptions'] = 'Yes'
            count_match +=1
       
        else:
            print('The real species is NOT in the response.')
            test.at[row, 'Real_Species_in_Response_descriptions'] = 'No'
    else:
        print('No real species to check in the response.')
        test.at[row, 'Real_Species_in_Response_descriptions'] = 'No species provided'
# Out:
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# No real species to check in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is in the response.
# No real species to check in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# No real species to check in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.

# %%
count_match
# Out:
# 63

# %% [markdown]
# ##### Study type:

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'Comment[IDR_Study_Accession]', 'Study_Title',
#        'Study_Type', 'Study_Type_Term_Source_REF', 'Study_Type_Term_Accession',
#        'Study_Description', 'Study_Key_Words', 'Study_Organism',
#        'Study_Organism_Term_Source_REF',
#        ...
#        'Experiment_Description_clean', 'Study_Description_word_count_clean',
#        'Experiment_Description_word_count_clean',
#        'Study_Description_clean_lemmatize', 'Study_Description_clean_entities',
#        'Experiment_Description_clean_lemmatize',
#        'Experiment_Description_clean_entities', 'Description_combined',
#        'Mistral_description_combined_species',
#        'Real_Species_in_Response_descriptions'],
#       dtype='str', length=234)

# %%
raw_experiment_types = test['Study_Type'].to_list()
raw_experiment_types
# Out:
# ['compound library screen',
#  'high content screen',
#  'microscopy assay',
#  'time-lapse imaging',
#  'histology',
#  'time-lapse imaging',
#  'high content screen',
#  'multiplexed immunofluorescence',
#  'high content screen',
#  'protein localization',
#  'time-lapse imaging',
#  'electron microscopy volume map',
#  'high content screen',
#  'time-lapse imaging',
#  'high content screen',
#  'high content screen',
#  'high content screen',
#  'in situ sequencing\n',
#  'protein localization',
#  'high content screen',
#  'time-lapse imaging',
#  'time-lapse imaging',
#  'high content screen',
#  'electron microscopy volume map',
#  'time-lapse imaging',
#  'protein localization ',
#  'high content screen',
#  'in-situ hybridization assay',
#  'electron microscopy volume map',
#  'spindle assembly\n',
#  'high content screen',
#  'protein localization',
#  'high content screen\n',
#  'time-lapse imaging\n',
#  'high content screen',
#  'high content screen',
#  'high content screen',
#  'high content screen',
#  'high content screen',
#  'time-lapse imaging',
#  'high content analysis of cells',
#  'dna sequencing',
#  'protein localization\n',
#  'myelination\n',
#  'histology',
#  'in-situ hybridization assay',
#  'image cytometry ',
#  'time-lapse imaging',
#  'high content screen of cells treated with a compound library',
#  'high content screen',
#  'high content screen',
#  'time-lapse imaging\n',
#  'histology',
#  'time-lapse imaging',
#  'high content screen',
#  'immunocytochemistry',
#  'infection',
#  'high content screen',
#  'microscopy assay',
#  'high content screen',
#  'high content screen',
#  'protein localization',
#  'imaging method',
#  'time-lapse imaging',
#  'high content screen',
#  'high content screen',
#  'phenotype',
#  'high content screen',
#  'histology',
#  'time-lapse imaging',
#  'metabolic network measurement\n',
#  'histology',
#  'time-lapse imaging',
#  'time-lapse imaging',
#  'fluorescence in situ hybridization',
#  'image segmentation',
#  'high content screen',
#  'imaging method',
#  'microscopy assay',
#  'time-lapse imaging',
#  'protein localization',
#  'time-lapse imaging',
#  'high content screen',
#  'histology',
#  'phenotype',
#  'high content screen',
#  'high content screen',
#  'histology',
#  'time-lapse imaging',
#  'high content screen',
#  'high content screen',
#  'multiplexed immunofluorescence',
#  'high content screen',
#  'high content screen',
#  'time-lapse imaging',
#  'high content screen',
#  'micrograph',
#  'high content screen\n',
#  'high content screen',
#  'in situ sequencing\n',
#  'high content screen',
#  'machine learning',
#  'high content screen',
#  'histology',
#  'morphogenesis',
#  'electron microscopy volume map',
#  'high content screen',
#  'time-lapse imaging',
#  'microscopy assay',
#  'high content screen',
#  'high content screen',
#  'histology',
#  'high content screen',
#  'high content screen',
#  'fluorescence in situ hybridization\n',
#  'response to cold',
#  'process of establishing viral infection\n',
#  'protein localization',
#  'x-chromosome inactivation',
#  'image cytometry ',
#  'high content screen',
#  'imaging method\n',
#  'histology',
#  'high content screen',
#  'high content screen                            \n',
#  'high content screen',
#  'high content screen',
#  'protein localization',
#  'time-lapse imaging',
#  'seqfish',
#  'high content screen',
#  'fluorescence in situ hybridization']

# %%
# Make a list with all types of experiments
# This list will be used to create a list of all types of experiments, removing duplicates and cleaning the data.
# ------------------------------------------------------------
list_experiment_types_clean = []
for element in raw_experiment_types:
    element_clean = element.strip().replace('\n', '')
    list_experiment_types_clean.append(element_clean)

# %%
experiment_types = list(set(list_experiment_types_clean))
experiment_types.sort()
len(experiment_types)
# Out:
# 30

# %%
experiment_types
# Out:
# ['compound library screen',
#  'dna sequencing',
#  'electron microscopy volume map',
#  'fluorescence in situ hybridization',
#  'high content analysis of cells',
#  'high content screen',
#  'high content screen of cells treated with a compound library',
#  'histology',
#  'image cytometry',
#  'image segmentation',
#  'imaging method',
#  'immunocytochemistry',
#  'in situ sequencing',
#  'in-situ hybridization assay',
#  'infection',
#  'machine learning',
#  'metabolic network measurement',
#  'micrograph',
#  'microscopy assay',
#  'morphogenesis',
#  'multiplexed immunofluorescence',
#  'myelination',
#  'phenotype',
#  'process of establishing viral infection',
#  'protein localization',
#  'response to cold',
#  'seqfish',
#  'spindle assembly',
#  'time-lapse imaging',
#  'x-chromosome inactivation']

# %%
', '.join(experiment_types)
# Out:
# 'compound library screen, dna sequencing, electron microscopy volume map, fluorescence in situ hybridization, high content analysis of cells, high content screen, high content screen of cells treated with a compound library, histology, image cytometry, image segmentation, imaging method, immunocytochemistry, in situ sequencing, in-situ hybridization assay, infection, machine learning, metabolic network measurement, micrograph, microscopy assay, morphogenesis, multiplexed immunofluorescence, myelination, phenotype, process of establishing viral infection, protein localization, response to cold, seqfish, spindle assembly, time-lapse imaging, x-chromosome inactivation'

# %%
for idx, row in test.iterrows():
    message = [
    {"role": "system", "content": i['Study_Description']},
    {"role": "user", "content": "Choose the experiment type for this study from the following list: " + ', '.join(experiment_types) + ". If you don't know, just say 'I don't know'."},
     ]
    outputs = pipe(message, max_new_tokens = 256)
    response = outputs[0]["generated_text"][-1]["content"]
    
    test.at[idx, "Mistral_description_study_type"] = response

    print(f'The row {idx} has been proceed.')
# Out:
# The row 0 has been proceed.
# The row 1 has been proceed.
# The row 2 has been proceed.
# The row 3 has been proceed.
# The row 4 has been proceed.
# The row 5 has been proceed.
# The row 6 has been proceed.
# The row 7 has been proceed.
# The row 8 has been proceed.
# The row 9 has been proceed.
# The row 10 has been proceed.
# The row 11 has been proceed.
# The row 12 has been proceed.
# The row 13 has been proceed.
# The row 14 has been proceed.
# The row 15 has been proceed.
# The row 16 has been proceed.
# The row 17 has been proceed.
# The row 18 has been proceed.
# The row 19 has been proceed.
# The row 20 has been proceed.
# The row 21 has been proceed.
# The row 22 has been proceed.
# The row 23 has been proceed.
# The row 24 has been proceed.
# The row 25 has been proceed.
# The row 26 has been proceed.
# The row 27 has been proceed.
# The row 28 has been proceed.
# The row 29 has been proceed.
# The row 30 has been proceed.
# The row 31 has been proceed.
# The row 32 has been proceed.
# The row 33 has been proceed.
# The row 34 has been proceed.
# The row 35 has been proceed.
# The row 36 has been proceed.
# The row 37 has been proceed.
# The row 38 has been proceed.
# The row 39 has been proceed.
# The row 40 has been proceed.
# The row 41 has been proceed.
# The row 42 has been proceed.
# The row 43 has been proceed.
# The row 44 has been proceed.
# The row 45 has been proceed.
# The row 46 has been proceed.
# The row 47 has been proceed.
# The row 48 has been proceed.
# The row 49 has been proceed.
# The row 50 has been proceed.
# The row 51 has been proceed.
# The row 52 has been proceed.
# The row 53 has been proceed.
# The row 54 has been proceed.
# The row 55 has been proceed.
# The row 56 has been proceed.
# The row 57 has been proceed.
# The row 58 has been proceed.
# The row 59 has been proceed.
# The row 60 has been proceed.
# The row 61 has been proceed.
# The row 62 has been proceed.
# The row 63 has been proceed.
# The row 64 has been proceed.
# The row 65 has been proceed.
# The row 66 has been proceed.
# The row 67 has been proceed.
# The row 68 has been proceed.
# The row 69 has been proceed.
# The row 70 has been proceed.
# The row 71 has been proceed.
# The row 72 has been proceed.
# The row 73 has been proceed.
# The row 74 has been proceed.
# The row 75 has been proceed.
# The row 76 has been proceed.
# The row 77 has been proceed.
# The row 78 has been proceed.
# The row 79 has been proceed.
# The row 80 has been proceed.
# The row 81 has been proceed.
# The row 82 has been proceed.
# The row 83 has been proceed.
# The row 84 has been proceed.
# The row 85 has been proceed.
# The row 86 has been proceed.
# The row 87 has been proceed.
# The row 88 has been proceed.
# The row 89 has been proceed.
# The row 90 has been proceed.
# The row 91 has been proceed.
# The row 92 has been proceed.
# The row 93 has been proceed.
# The row 94 has been proceed.
# The row 95 has been proceed.
# The row 96 has been proceed.
# The row 97 has been proceed.
# The row 98 has been proceed.
# The row 99 has been proceed.
# The row 100 has been proceed.
# The row 101 has been proceed.
# The row 102 has been proceed.
# The row 103 has been proceed.
# The row 104 has been proceed.
# The row 105 has been proceed.
# The row 106 has been proceed.
# The row 107 has been proceed.
# The row 108 has been proceed.
# The row 109 has been proceed.
# The row 110 has been proceed.
# The row 111 has been proceed.
# The row 112 has been proceed.
# The row 113 has been proceed.
# The row 114 has been proceed.
# The row 115 has been proceed.
# The row 116 has been proceed.
# The row 117 has been proceed.
# The row 118 has been proceed.
# The row 119 has been proceed.
# The row 120 has been proceed.
# The row 121 has been proceed.
# The row 122 has been proceed.
# The row 123 has been proceed.
# The row 124 has been proceed.
# The row 125 has been proceed.
# The row 126 has been proceed.
# The row 127 has been proceed.
# The row 128 has been proceed.
# The row 129 has been proceed.
# The row 130 has been proceed.
# The row 131 has been proceed.

# %%
df_IDR['Study_Type'][4]
# Out:
# 'histology'

# %%
df_IDR['Mistral_description_study_type'][4]
# Out:
# " The experiment type for this study is 'In Situ Hybridization Assay'."

# %%
count_match_study_type = 0
for row, i in test.iterrows():
    
    if isinstance(i['Study_Type'], str) and i['Study_Type'].strip() != '':

        real_study = i['Study_Type']
        #print(real_study)
        response = i['Mistral_description_study_type']
        #print(response)
        clean_response = remove_special_characters(response)
        lower_clean_response = clean_response.lower()

        if real_study in lower_clean_response:
            print('The real study type is in the response.')
            test.at[row, 'Real_Study_Type_in_Response_descriptions'] = 'Yes'
            count_match_study_type +=1
        else:
            print('The real study type is NOT in the response.')
            test.at[row, 'Real_Study_Type_in_Response_descriptions'] = 'No'
    else:
        print('No real study type to check in the response.')
        test.at[row, 'Real_Study_Type_in_Response_descriptions'] = 'No species provided'
# Out:
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.
# The real study type is NOT in the response.

# %%
count_match_study_type
# Out:
# 0

# %% [markdown]
# #### All dataframe - whole info

# %%
#test_wo_species = test.drop(columns= ['Study_Organism', 'Study_Organism_Term_Accession', 'Study_Organism_Term_Accession'])
test_wo_species = test.drop(columns= ['Study_Organism'])
test_wo_species
# Out:
#      Unnamed: 0 Comment[IDR_Study_Accession]  \
# 0             0                      idr0092
# 1             1                      idr0016
# 2             2                      idr0079
# 3             3                      idr0067
# 4             4                      idr0134
# ..          ...                          ...
# 127         127                      idr0023
# 128         128                      idr0038
# 129         129                      idr0138
# 130         130                      idr0128
# 131         131                      idr0123
#
#                                            Study_Title  \
# 0    a semi-automated organoid screening method dem...
# 1    human u2os cells - compound cell-painting expe...
# 2    an image-based data-driven analysis of cellula...
# 3    meiotic cellular rejuvenation is coupled to nu...
# 4    reference bioimaging dataset to assess the phe...
# ..                                                 ...
# 127  nuclear pore scaffold structure analyzed by su...
# 128  ex vivo live cell tracking in kidney organoids...
# 129  integration of spatial and single-cell transcr...
# 130  parallel compound screen for infection modulat...
# 131  simultaneous visualization of dna loci in sing...
#
#                              Study_Type Study_Type_Term_Source_REF  \
# 0               compound library screen                        efo
# 1                   high content screen                        efo
# 2                      microscopy assay                        efo
# 3                    time-lapse imaging                       omit
# 4                             histology                       none
# ..                                  ...                        ...
# 127                protein localization                        efo
# 128                  time-lapse imaging                       omit
# 129                             seqfish                        efo
# 130                 high content screen                        efo
# 131  fluorescence in situ hybridization                       ncit
#
#     Study_Type_Term_Accession  \
# 0                 efo_0007553
# 1                 efo_0007550
# 2                 efo_0002909
# 3                omit_0027490
# 4                        none
# ..                        ...
# 127                go:0008104
# 128              omit_0027490
# 129               efo_0008991
# 130               efo_0007550
# 131               ncit_c17563
#
#                                      Study_Description  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                         Study_Key_Words Study_Organism_Term_Source_REF  \
# 0                             organoids                      ncbitaxon
# 1                                   NaN                      ncbitaxon
# 2                        image analysis                      ncbitaxon
# 3                               meiosis                      ncbitaxon
# 4                            phenotypes                      ncbitaxon
# ..                                  ...                            ...
# 127                                 NaN                      ncbitaxon
# 128                                 NaN                      ncbitaxon
# 129                             seqfish                      ncbitaxon
# 130                   influenza a virus                      ncbitaxon
# 131  fluorescence in situ hybridization                      ncbitaxon
#
#     Study_Organism_Term_Accession  ...  \
# 0                           10090  ...
# 1                  ncbitaxon_9606  ...
# 2                            7955  ...
# 3                            4932  ...
# 4                          264775  ...
# ..                            ...  ...
# 127                ncbitaxon_9606  ...
# 128               ncbitaxon_10090  ...
# 129                         10090  ...
# 130                          9606  ...
# 131                          9606  ...
#
#      Experiment_Description_word_count_clean  \
# 0                                          0
# 1                                          0
# 2                                         20
# 3                                         29
# 4                                        508
# ..                                       ...
# 127                                       11
# 128                                      161
# 129                                       19
# 130                                        0
# 131                                      144
#
#                      Study_Description_clean_lemmatize  \
# 0    intestinal organoid excellent model study epit...
# 1    phenotypic profiling attempt summarize multipa...
# 2    analysis cell morphology intracellular organiz...
# 3    production healthy gamete meiosis rely quality...
# 4    present reference dataset contain macroscopic ...
# ..                                                 ...
# 127  much lifes essential molecular machinery consi...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  molecular profiling single cell advance knowle...
# 130  viral infectious disease span myriad malady in...
# 131  describe dataset obtain apply recently develop...
#
#                       Study_Description_clean_entities  \
# 0    [intestinal, model study, epithelial biology, ...
# 1    [phenotypic profiling, multiparametric analysi...
# 2    [morphology, intracellular, organization, zebr...
# 3    [production, healthy, meiosis, quality, distri...
# 4    [dataset, macroscopic, phenotypic property spe...
# ..                                                 ...
# 127  [lifes, molecular machinery, protein assembly,...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [molecular profiling, single cell advance, dis...
# 130  [viral infectious disease, immunosuppression, ...
# 131  [dataset, ifish, pipeline, small size, kilobas...
#
#                 Experiment_Description_clean_lemmatize  \
# 0                                                  NaN
# 1                                                  NaN
# 2    confocal imaging fixed sample zebrafish poster...
# 3    fix cell fluorescence microscopy transmission ...
# 4    representative voucher specimen receive herbar...
# ..                                                 ...
# 127  systematic immunolabelling complex monomeric e...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  seqfish study sagittal section mouse embryo so...
# 130                                                NaN
# 131  dataset replicate experimental design consist ...
#
#                  Experiment_Description_clean_entities  \
# 0                                                   []
# 1                                                   []
# 2    [confocal imaging, posterior lateral line, pri...
# 3    [cell fluorescence microscopy, image, yeast, m...
# 4    [specimen, herbaria, sample diplophyllum taxif...
# ..                                                 ...
# 127  [systematic immunolabelling, complex, monomeri...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [seqfish study, sagittal section, mouse, embry...
# 130                                                 []
# 131  [dataset, replicate, experimental design, prob...
#
#                                   Description_combined  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                   Mistral_description_combined_species  \
# 0     I don't have real-time access to databases or...
# 1     I don't know. The context provided does not s...
# 2     Based on the context provided, the scientific...
# 3     Based on the context provided, the scientific...
# 4     Based on the context provided, the three scie...
# ..                                                 ...
# 127   Based on the context provided, the three scie...
# 128   Based on the context provided, the three scie...
# 129   In the context provided, the species used in ...
# 130   Based on the context provided, the three scie...
# 131   I don't know. The context provided does not s...
#
#     Real_Species_in_Response_descriptions  \
# 0                                     Yes
# 1                                      No
# 2                                     Yes
# 3                                      No
# 4                                      No
# ..                                    ...
# 127                                   Yes
# 128                                   Yes
# 129                                   Yes
# 130                                    No
# 131                                    No
#
#                         Mistral_description_study_type  \
# 0     The experiment type for this study is 'In Sit...
# 1     The experiment type for this study is 'In Sit...
# 2     The experiment type for this study is 'In Sit...
# 3     The experiment type for this study is 'In Sit...
# 4     The experiment type for this study is 'In Sit...
# ..                                                 ...
# 127   The experiment type for this study is 'In Sit...
# 128   The experiment type for this study is 'In Sit...
# 129   The experiment type for this study is 'In Sit...
# 130   The experiment type for this study is 'In Sit...
# 131   The experiment type for this study is 'In Sit...
#
#     Real_Study_Type_in_Response_descriptions
# 0                                         No
# 1                                         No
# 2                                         No
# 3                                         No
# 4                                         No
# ..                                       ...
# 127                                       No
# 128                                       No
# 129                                       No
# 130                                       No
# 131                                       No
#
# [132 rows x 235 columns]

# %% [markdown]
# ### Clasical pathway

# %%
#pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bionlp13cg_md-0.5.4.tar.gz

# %%
#pip install spacy==3.7.4

# %%
import spacy
import time

# %%
# Load the spaCy model
## This model have the tags on it. One of them is 'ORG' so I choose it to extract the species.

nlp = spacy.load("en_ner_bionlp13cg_md") 
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'attribute_ruler', 'lemmatizer', 'parser', 'ner']
# /opt/conda/lib/python3.11/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
# Function to extract species from the combined descriptions
# This function takes a text input, processes it with the spaCy model, and extracts named entities related to species.
# It returns a dictionary with the entity labels as keys and the corresponding entity texts as values.
# The function uses the spaCy model to identify named entities in the text and groups them by their entity labels.
# The output is a dictionary where the keys are the entity labels (e.g., 'ORG' for organisms) and the values are lists of entity texts that correspond to those labels.
# ------------------------------------------------------------  

def extract_species(text):
    doc= nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]

    dictionary_entities = {}
    for k,v in entities:
        if v not in dictionary_entities:
            dictionary_entities[v]=[]
        dictionary_entities[v].append(k)
    
    return dictionary_entities

# %%
dfs = df_biodare2
dfs = dfs.reset_index(drop=True)

# %%
def extract_entities(doc):
    out = {}
    for ent in doc.ents:
        out.setdefault(ent.label_, []).append(ent.text)
    return out

texts = dfs["Description_combined"].fillna("").astype(str).tolist()

results = []
for doc in nlp.pipe(texts):
    results.append(extract_entities(doc))

dfs["Entities_SpaCy"] = results   # keep as dicts
# or strings:
# dfs["Entities_SpaCy"] = [json.dumps(r) for r in results]

# %%
dfs
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#       Name_clean_entities                            Purpose_clean_lemmatize  \
# 0               [control]                                      global search
# 1                      []  timet focus important general biological probl...
# 2                [ld lhy]  experiment reparameterize clock model without ...
# 3       [lhy long marker]  test period change seedlle growth topcount wt ...
# 4       [lhy long marker]  test period change seedlle growth topcount wt ...
# ...                   ...                                                ...
# 20466        [niwa, mrna]  arabidopsis thaliana flower time regulate circ...
# 20467                  []                       photoperiod alteration study
# 20468          [analysis]  compare different sibling parentalcontrol stra...
# 20469                  []  dynamic transition lightdark cycle different p...
# 20470            [sdtold]  dynamic transition lightdark cycle different p...
#
#                                   Purpose_clean_entities  \
# 0                                               [global]
# 1      [biological, plant metabolism, growth regulate...
# 2          [experiment, clock model, exogenous, sucrose]
# 3                                       [seedlle growth]
# 4                                       [seedlle growth]
# ...                                                  ...
# 20466  [arabidopsis thaliana, flower, circadian, cloc...
# 20467                                      [photoperiod]
# 20468  [compare, sibling, parentalcontrol, circadian,...
# 20469  [dynamic transition lightdark cycle, photoperi...
# 20470  [dynamic transition lightdark cycle, photoperi...
#
#                              Description_clean_lemmatize  \
# 0      null growth condition const w experimental con...
# 1      wt mutant biological duplicate diurnal light h...
# 2      literature datum temp aurora seedling entrain ...
# 3      period change development genetic screen clock...
# 4      period change development genetic screen clock...
# ...                                                  ...
# 20466  null growth condition const w ld experimental ...
# 20467  luc image cycle constant light replicate exper...
# 20468  null growth condition condition const w experi...
# 20469  plant entrain day experimental condition day d...
# 20470  ptoc plate pcab lhy plate control plate toc pl...
#
#                               Description_clean_entities  \
# 0        [null growth condition, experimental condition]
# 1      [mutant, biological, diurnal light harvest, tr...
# 2      [literature datum, seedling, day, white light ...
# 3      [development, genetic screen, clock mutant, de...
# 4      [development, genetic screen, clock mutant, de...
# ...                                                  ...
# 20466    [null growth condition, experimental condition]
# 20467                                       [experiment]
# 20468  [null growth condition, condition, experimenta...
# 20469  [plant, experimental condition, day, day, red ...
# 20470                           [ptoc plate, plhy plate]
#
#                                 Comments_clean_lemmatize  \
# 0                                                    NaN
# 1      mutant harvest day rest due early flowering ph...
# 2      sample lose several genotype curate andrew mil...
# 3      datum collection victoria hibberd can septembe...
# 4      datum collection victoria hibberd can septembe...
# ...                                                  ...
# 20466                                                NaN
# 20467  image start fungal infection gi lhy mutant pla...
# 20468                                                NaN
# 20469  partner experiment growth condition const w ld...
# 20470  several control relevant parallel experiment a...
#
#                                  Comments_clean_entities  \
# 0                                                     []
# 1      [mutant, day, flowering, phenotype, experiment...
# 2      [sample lose, genotype, millar, manually edit ...
# 3      [datum collection victoria, hibberd, millar, r...
# 4      [datum collection victoria, hibberd, millar, r...
# ...                                                  ...
# 20466                                                 []
# 20467  [image, fungal infection, lhy group, datum, an...
# 20468                                                 []
# 20469  [experiment, growth condition, experimental co...
# 20470  [control, culture plate, marker, marker, plate...
#
#                                     Description_combined  \
# 0      controls global search null growth conditions:...
# 1      timet wp1.1 qrt-pcr elf3 ld timet focuses on a...
# 2      q-pcr ld (12:12) 17c lhy experiment to reparam...
# 3      cca1 lhy long #1 cca1 marker test for period c...
# 4      cca1 lhy long #1 cab2 marker test for period c...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053: 4x3:21-ll photoperiod alteration study...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld re-entrainment dynamics during ...
# 20470  sdtold 260410 re-entrainment dynamics during t...
#
#                       Llama_description_combined_species  \
# 0      Based on the context, I can infer that the stu...
# 1      Based on the context provided, I can make some...
# 2      Based on the context provided, the following t...
# 3      Based on the context, I can make some educated...
# 4      Based on the context, it appears that the stud...
# ...                                                  ...
# 20466                                                NaN
# 20467                                                NaN
# 20468                                                NaN
# 20469                                                NaN
# 20470                                                NaN
#
#                                           Entities_SpaCy
# 0                                   {'CANCER': ['ll24']}
# 1      {'GENE_OR_GENE_PRODUCT': ['elf3-4'], 'CELL': [...
# 2      {'GENE_OR_GENE_PRODUCT': ['aurora', 'prr7-9-',...
# 3      {'SIMPLE_CHEMICAL': ['cca lhy', 'lhy'], 'ORGAN...
# 4      {'SIMPLE_CHEMICAL': ['cca lhy', 'lhy'], 'ORGAN...
# ...                                                  ...
# 20466  {'SIMPLE_CHEMICAL': ['fkf1', 'lhy', 'lhy'], 'G...
# 20467  {'GENE_OR_GENE_PRODUCT': ['luc', 'toc1'], 'SIM...
# 20468                                                 {}
# 20469  {'CELL': ['a. thaliana'], 'GENE_OR_GENE_PRODUC...
# 20470  {'GENE_OR_GENE_PRODUCT': ['luc', 'toc1'], 'SIM...
#
# [20471 rows x 38 columns]

# %%
dfs["Species_SpaCy"] = dfs["Entities_SpaCy"].apply(
    lambda d: d.get("ORGANISM", "Not found") if isinstance(d, dict) else "Not found"
)

# %%
dfs
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#                                  Purpose_clean_lemmatize  \
# 0                                          global search
# 1      timet focus important general biological probl...
# 2      experiment reparameterize clock model without ...
# 3      test period change seedlle growth topcount wt ...
# 4      test period change seedlle growth topcount wt ...
# ...                                                  ...
# 20466  arabidopsis thaliana flower time regulate circ...
# 20467                       photoperiod alteration study
# 20468  compare different sibling parentalcontrol stra...
# 20469  dynamic transition lightdark cycle different p...
# 20470  dynamic transition lightdark cycle different p...
#
#                                   Purpose_clean_entities  \
# 0                                               [global]
# 1      [biological, plant metabolism, growth regulate...
# 2          [experiment, clock model, exogenous, sucrose]
# 3                                       [seedlle growth]
# 4                                       [seedlle growth]
# ...                                                  ...
# 20466  [arabidopsis thaliana, flower, circadian, cloc...
# 20467                                      [photoperiod]
# 20468  [compare, sibling, parentalcontrol, circadian,...
# 20469  [dynamic transition lightdark cycle, photoperi...
# 20470  [dynamic transition lightdark cycle, photoperi...
#
#                              Description_clean_lemmatize  \
# 0      null growth condition const w experimental con...
# 1      wt mutant biological duplicate diurnal light h...
# 2      literature datum temp aurora seedling entrain ...
# 3      period change development genetic screen clock...
# 4      period change development genetic screen clock...
# ...                                                  ...
# 20466  null growth condition const w ld experimental ...
# 20467  luc image cycle constant light replicate exper...
# 20468  null growth condition condition const w experi...
# 20469  plant entrain day experimental condition day d...
# 20470  ptoc plate pcab lhy plate control plate toc pl...
#
#                               Description_clean_entities  \
# 0        [null growth condition, experimental condition]
# 1      [mutant, biological, diurnal light harvest, tr...
# 2      [literature datum, seedling, day, white light ...
# 3      [development, genetic screen, clock mutant, de...
# 4      [development, genetic screen, clock mutant, de...
# ...                                                  ...
# 20466    [null growth condition, experimental condition]
# 20467                                       [experiment]
# 20468  [null growth condition, condition, experimenta...
# 20469  [plant, experimental condition, day, day, red ...
# 20470                           [ptoc plate, plhy plate]
#
#                                 Comments_clean_lemmatize  \
# 0                                                    NaN
# 1      mutant harvest day rest due early flowering ph...
# 2      sample lose several genotype curate andrew mil...
# 3      datum collection victoria hibberd can septembe...
# 4      datum collection victoria hibberd can septembe...
# ...                                                  ...
# 20466                                                NaN
# 20467  image start fungal infection gi lhy mutant pla...
# 20468                                                NaN
# 20469  partner experiment growth condition const w ld...
# 20470  several control relevant parallel experiment a...
#
#                                  Comments_clean_entities  \
# 0                                                     []
# 1      [mutant, day, flowering, phenotype, experiment...
# 2      [sample lose, genotype, millar, manually edit ...
# 3      [datum collection victoria, hibberd, millar, r...
# 4      [datum collection victoria, hibberd, millar, r...
# ...                                                  ...
# 20466                                                 []
# 20467  [image, fungal infection, lhy group, datum, an...
# 20468                                                 []
# 20469  [experiment, growth condition, experimental co...
# 20470  [control, culture plate, marker, marker, plate...
#
#                                     Description_combined  \
# 0      controls global search null growth conditions:...
# 1      timet wp1.1 qrt-pcr elf3 ld timet focuses on a...
# 2      q-pcr ld (12:12) 17c lhy experiment to reparam...
# 3      cca1 lhy long #1 cca1 marker test for period c...
# 4      cca1 lhy long #1 cab2 marker test for period c...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053: 4x3:21-ll photoperiod alteration study...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld re-entrainment dynamics during ...
# 20470  sdtold 260410 re-entrainment dynamics during t...
#
#                       Llama_description_combined_species  \
# 0      Based on the context, I can infer that the stu...
# 1      Based on the context provided, I can make some...
# 2      Based on the context provided, the following t...
# 3      Based on the context, I can make some educated...
# 4      Based on the context, it appears that the stud...
# ...                                                  ...
# 20466                                                NaN
# 20467                                                NaN
# 20468                                                NaN
# 20469                                                NaN
# 20470                                                NaN
#
#                                           Entities_SpaCy  \
# 0                                   {'CANCER': ['ll24']}
# 1      {'GENE_OR_GENE_PRODUCT': ['elf3-4'], 'CELL': [...
# 2      {'GENE_OR_GENE_PRODUCT': ['aurora', 'prr7-9-',...
# 3      {'SIMPLE_CHEMICAL': ['cca lhy', 'lhy'], 'ORGAN...
# 4      {'SIMPLE_CHEMICAL': ['cca lhy', 'lhy'], 'ORGAN...
# ...                                                  ...
# 20466  {'SIMPLE_CHEMICAL': ['fkf1', 'lhy', 'lhy'], 'G...
# 20467  {'GENE_OR_GENE_PRODUCT': ['luc', 'toc1'], 'SIM...
# 20468                                                 {}
# 20469  {'CELL': ['a. thaliana'], 'GENE_OR_GENE_PRODUC...
# 20470  {'GENE_OR_GENE_PRODUCT': ['luc', 'toc1'], 'SIM...
#
#                   Species_SpaCy
# 0                     Not found
# 1                     Not found
# 2      [clock-mutant seedlings]
# 3                     Not found
# 4                     Not found
# ...                         ...
# 20466                 Not found
# 20467                 Not found
# 20468                 Not found
# 20469                 Not found
# 20470                 Not found
#
# [20471 rows x 39 columns]

# %%
start_time = time.time()

for i, item in dfs.iterrows():
    list_species_spacy = item['Species_SpaCy']
    list_species_scientific_name = []

    for x in list_species_spacy:
        values = x.split(' ')
        #print(values)
        for unique_value in values:
            #print(unique_value)
            
            url = f'https://www.ebi.ac.uk/ena/taxonomy/rest/any-name/{unique_value}'
            #print(url)

            response = requests.get(url)
        
            if response.status_code == 200:
                data = response.json()
                #print(data)
                if data:
                    scientific_name = data[0]['scientificName']
                    #print("found")

                    list_species_scientific_name.append(scientific_name)
                    print(f"Scientific name for {x}: {scientific_name}")
                else:
                    scientific_name = 'Not found'
                    print(f"Scientific name for {x}: {scientific_name}")

    dfs.at[i, 'Species_Scientific_Name_SciSpacy'] = str(list_species_scientific_name)

end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")
# Out:
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for clock-mutant seedlings: Not found
# Scientific name for clock-mutant seedlings: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for blue leds: Not found
# Scientific name for blue leds: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for mouse bmal-luciferase: Mus musculus
# Scientific name for mouse bmal-luciferase: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for luciferase: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for lhy-luc: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for john innes cereal: Not found
# Scientific name for john innes cereal: Not found
# Scientific name for john innes cereal: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for lentiviral: Not found
# Scientific name for hamsters: Cricetinae
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for blue leds: Not found
# Scientific name for blue leds: Not found
# Scientific name for blue leds: Not found
# Scientific name for blue leds: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for brassica napus leaf: Brassica
# Scientific name for brassica napus leaf: Not found
# Scientific name for brassica napus leaf: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for mouse: Mus musculus
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# ...
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for cca1luc leaf: Not found
# Scientific name for cca1luc leaf: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for zebrafish liver: Danio rerio
# Scientific name for zebrafish liver: Not found
# Scientific name for zebrafish liver: Danio rerio
# Scientific name for zebrafish liver: Not found
# Scientific name for male: Not found
# Scientific name for female: Not found
# Scientific name for zebrafish liver: Danio rerio
# Scientific name for zebrafish liver: Not found
# Scientific name for zebrafish: Danio rerio
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for blue light - orca: Not found
# Scientific name for blue light - orca: Not found
# Scientific name for blue light - orca: Not found
# Scientific name for blue light - orca: Orcinus orca
# Scientific name for blue light: Not found
# Scientific name for blue light: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for danio rerio: Danio
# Scientific name for danio rerio: Not found
# Scientific name for zebrafish pen2 protein exsit rhythm: Danio rerio
# Scientific name for zebrafish pen2 protein exsit rhythm: Not found
# Scientific name for zebrafish pen2 protein exsit rhythm: Not found
# Scientific name for zebrafish pen2 protein exsit rhythm: Not found
# Scientific name for zebrafish pen2 protein exsit rhythm: Not found
# Scientific name for zebrafish liver 12: Danio rerio
# Scientific name for zebrafish liver 12: Not found
# Scientific name for zebrafish liver 12: Not found
# Scientific name for zebrafish liver: Danio rerio
# Scientific name for zebrafish liver: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for chicken chicken: Gallus gallus
# Scientific name for chicken chicken: Gallus gallus
# Scientific name for broiler: Not found
# Scientific name for chicken: Gallus gallus
# Scientific name for broiler: Not found
# Scientific name for chicken: Gallus gallus
# Scientific name for chicken: Gallus gallus
# Scientific name for human: Homo sapiens
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for human: Homo sapiens
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found
# Scientific name for f: Not found
# Scientific name for o: Not found
# Scientific name for u: Not found
# Scientific name for n: Not found
# Scientific name for d: Not found
# Scientific name for N: Not found
# Scientific name for o: Not found
# Scientific name for t: Not found

# %%
import requests
import pandas as pd
import time

start_time = time.time()

def get_scientific_names(series):
    # Create a list to hold the results
    scientific_names = []
    
    # Iterate over each item in the series
    for item in series:
        words = item.split(' ')
        item_scientific_names = []
        
        # Iterate over each word
        for word in words:
            url = f'https://www.ebi.ac.uk/ena/taxonomy/rest/any-name/{word}'
            response = requests.get(url)
            
            if response.status_code == 200:
                data = response.json()
                if data:
                    scientific_name = data[0]['scientificName']
                    item_scientific_names.append(scientific_name)
                    print(f"Scientific name for {word}: {scientific_name}")
                else:
                    item_scientific_names.append('Not found')
                    print(f"Scientific name for {word}: Not found")
        
        scientific_names.append(str(item_scientific_names))
    
    return scientific_names

dfs['Species_Scientific_Name_SciSpacy'] = get_scientific_names(dfs['Species_SpaCy'])

end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")

# %%
dfs
# Out:
#      Unnamed: 0 Comment[IDR_Study_Accession]  \
# 0             0                      idr0092
# 1             1                      idr0016
# 2             2                      idr0079
# 3             3                      idr0067
# 4             4                      idr0134
# ..          ...                          ...
# 127         127                      idr0023
# 128         128                      idr0038
# 129         129                      idr0138
# 130         130                      idr0128
# 131         131                      idr0123
#
#                                            Study_Title  \
# 0    a semi-automated organoid screening method dem...
# 1    human u2os cells - compound cell-painting expe...
# 2    an image-based data-driven analysis of cellula...
# 3    meiotic cellular rejuvenation is coupled to nu...
# 4    reference bioimaging dataset to assess the phe...
# ..                                                 ...
# 127  nuclear pore scaffold structure analyzed by su...
# 128  ex vivo live cell tracking in kidney organoids...
# 129  integration of spatial and single-cell transcr...
# 130  parallel compound screen for infection modulat...
# 131  simultaneous visualization of dna loci in sing...
#
#                              Study_Type Study_Type_Term_Source_REF  \
# 0               compound library screen                        efo
# 1                   high content screen                        efo
# 2                      microscopy assay                        efo
# 3                    time-lapse imaging                       omit
# 4                             histology                       none
# ..                                  ...                        ...
# 127                protein localization                        efo
# 128                  time-lapse imaging                       omit
# 129                             seqfish                        efo
# 130                 high content screen                        efo
# 131  fluorescence in situ hybridization                       ncit
#
#     Study_Type_Term_Accession  \
# 0                 efo_0007553
# 1                 efo_0007550
# 2                 efo_0002909
# 3                omit_0027490
# 4                        none
# ..                        ...
# 127                go:0008104
# 128              omit_0027490
# 129               efo_0008991
# 130               efo_0007550
# 131               ncit_c17563
#
#                                      Study_Description  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                         Study_Key_Words              Study_Organism  \
# 0                             organoids                mus musculus
# 1                                   NaN                homo sapiens
# 2                        image analysis                 danio rerio
# 3                               meiosis  saccharomyces cerevisiae\n
# 4                            phenotypes       diplophyllum albicans
# ..                                  ...                         ...
# 127                                 NaN                homo sapiens
# 128                                 NaN                mus musculus
# 129                             seqfish                mus musculus
# 130                   influenza a virus                homo sapiens
# 131  fluorescence in situ hybridization                homo sapiens
#
#     Study_Organism_Term_Source_REF  ... Study_Description_word_count_clean  \
# 0                        ncbitaxon  ...                                 89
# 1                        ncbitaxon  ...                                182
# 2                        ncbitaxon  ...                                 60
# 3                        ncbitaxon  ...                                 99
# 4                        ncbitaxon  ...                                 32
# ..                             ...  ...                                ...
# 127                      ncbitaxon  ...                                 75
# 128                      ncbitaxon  ...                                 79
# 129                      ncbitaxon  ...                                100
# 130                      ncbitaxon  ...                                 99
# 131                      ncbitaxon  ...                                 51
#
#      Experiment_Description_word_count_clean  \
# 0                                          0
# 1                                          0
# 2                                         20
# 3                                         29
# 4                                        508
# ..                                       ...
# 127                                       11
# 128                                      161
# 129                                       19
# 130                                        0
# 131                                      144
#
#                      Study_Description_clean_lemmatize  \
# 0    intestinal organoid excellent model study epit...
# 1    phenotypic profiling attempt summarize multipa...
# 2    analysis cell morphology intracellular organiz...
# 3    production healthy gamete meiosis rely quality...
# 4    present reference dataset contain macroscopic ...
# ..                                                 ...
# 127  much lifes essential molecular machinery consi...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  molecular profiling single cell advance knowle...
# 130  viral infectious disease span myriad malady in...
# 131  describe dataset obtain apply recently develop...
#
#                       Study_Description_clean_entities  \
# 0    [intestinal, model study, epithelial biology, ...
# 1    [phenotypic profiling, multiparametric analysi...
# 2    [morphology, intracellular, organization, zebr...
# 3    [production, healthy, meiosis, quality, distri...
# 4    [dataset, macroscopic, phenotypic property spe...
# ..                                                 ...
# 127  [lifes, molecular machinery, protein assembly,...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [molecular profiling, single cell advance, dis...
# 130  [viral infectious disease, immunosuppression, ...
# 131  [dataset, ifish, pipeline, small size, kilobas...
#
#                 Experiment_Description_clean_lemmatize  \
# 0                                                  NaN
# 1                                                  NaN
# 2    confocal imaging fixed sample zebrafish poster...
# 3    fix cell fluorescence microscopy transmission ...
# 4    representative voucher specimen receive herbar...
# ..                                                 ...
# 127  systematic immunolabelling complex monomeric e...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  seqfish study sagittal section mouse embryo so...
# 130                                                NaN
# 131  dataset replicate experimental design consist ...
#
#                  Experiment_Description_clean_entities  \
# 0                                                   []
# 1                                                   []
# 2    [confocal imaging, posterior lateral line, pri...
# 3    [cell fluorescence microscopy, image, yeast, m...
# 4    [specimen, herbaria, sample diplophyllum taxif...
# ..                                                 ...
# 127  [systematic immunolabelling, complex, monomeri...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [seqfish study, sagittal section, mouse, embry...
# 130                                                 []
# 131  [dataset, replicate, experimental design, prob...
#
#                                   Description_combined  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                                         Entities_SpaCy  \
# 0    {'CANCER': ['intestinal organoids', 'intestina...
# 1    {'CELL': ['cellular', 'u2os cells', 'cell', 'c...
# 2    {'CELL': ['cell', 'single-cell', 'cell', 'cell...
# 3    {'CELLULAR_COMPONENT': ['nuclear', 'nuclear', ...
# 4                                                   {}
# ..                                                 ...
# 127  {'CELLULAR_COMPONENT': ['nuclear', 'pores'], '...
# 128  {'ORGANISM': ['mouse kidney rudiment', 'e13.5 ...
# 129  {'CELL': ['cells', 'cells', 'single-cell', 'si...
# 130  {'CANCER': ['cancer'], 'ORGAN': ['organ'], 'OR...
# 131  {'CELLULAR_COMPONENT': ['dna', 'chromosome con...
#
#                                         Species_SpaCy  \
# 0                                           Not found
# 1                                           Not found
# 2       [zebrafish posterior lateral line primordium]
# 3                                           Not found
# 4                                           Not found
# ..                                                ...
# 127                                         Not found
# 128  [mouse kidney rudiment, e13.5 embryonic kidneys]
# 129                                   [mouse embryos]
# 130   [human, human rhinovirus, herpes simplex virus]
# 131                                     [human cells]
#
#                       Species_Scientific_Name_SciSpacy
# 0                                                   []
# 1                                                   []
# 2                                      ['Danio rerio']
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 127                                                 []
# 128                                   ['Mus musculus']
# 129                                   ['Mus musculus']
# 130  ['Homo sapiens', 'Homo sapiens', 'Enterovirus'...
# 131                                   ['Homo sapiens']
#
# [132 rows x 235 columns]

# %%
dfs.to_csv("work_in_progress_20260613.csv")

# %%
def remove_special_characters(text):
    """
    This function removes special characters from the text.
    :param text: text
    :return: text without special characters
    """
    cleaned_string = re.sub(r'[?|$|.|!|@|#|%|^|&|*|(|)|-|_|+|=|;|:|,|<|>|/|{|}|[|]|~|`|\'|\"|\\]',r'', text)

    return cleaned_string

# %%
for i, item in dfs.iterrows():
    if isinstance(item['Study_Organism'], str) and item['Study_Organism'].strip() != '':
        real_specie = item['Study_Organism']
        scispacy_specie = item['Species_Scientific_Name_SciSpacy']
        clean_spacy_specie = remove_special_characters(scispacy_specie).lower()

        if real_specie in clean_spacy_specie:

            print('The real species is in SciSpacy')
            dfs.at[i, 'Specie_found_Scispacy'] = 'Yes'
        else:
            print('The real species is NOT in SciSpacy')
            dfs.at[i, 'Specie_found_Scispacy'] = 'No'
    else:
        print('No real species to check in SciSpacy')
        dfs.at[i, 'Specie_found_Scispacy'] = 'No species provided'
# Out:
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# No real species to check in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# No real species to check in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# No real species to check in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is NOT in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy
# The real species is in SciSpacy

# %%
dfs['Specie_found_Scispacy'].value_counts()

# %%
# Use a pipeline for question answering with BioBERT
# This pipeline is used to answer questions based on the context provided.
# It uses the BioBERT model trained on the SQuAD dataset for question answering.
# The model is loaded with the device set to 'mps' for MacOS GPU support
# and is used to answer questions related to biomedical texts.
# The model is specifically designed for question answering tasks in the biomedical domain.
# ------------------------------------------------------------
from transformers import pipeline
pipe = pipeline("question-answering", model="dmis-lab/biobert-large-cased-v1.1-squad")
# Out:
# Device set to use cuda:0

# %%
from transformers import pipeline
import time

# Load the BioBERT model and create a pipeline for question answering
qa_pipeline_biobert = pipeline("question-answering", model="dmis-lab/biobert-large-cased-v1.1-squad")

start_time = time.time()

for i, item in dfs.iterrows():
    specie_found = item['Specie_found_Scispacy']

    if specie_found.startswith("No"):
        # Use the BioBERT pipeline to answer the question
        text = item['Description_combined']
        question = 'what species was used in the experiment?'

        result = qa_pipeline_biobert(question=question, context=text)
        print(f"Row {i}: {result['answer']}")
        dfs.at[i, 'Species_BioBERT'] = result['answer']

    else:
        print(f"Row {i}: The species was already found in the previous steps.")

end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")
# Out:
# Device set to use cuda:0
# Row 0: small intestinal crypts were isolated
# Row 1: u2os
# Row 2: The species was already found in the previous steps.
# Row 3: budding yeast
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Row 4: diplophyllum taxifolium
# Row 5: The species was already found in the previous steps.
# Row 6: hela
# Row 7: The species was already found in the previous steps.
# Row 8: yeast
# Row 9: The species was already found in the previous steps.
# Row 10: The species was already found in the previous steps.
# Row 11: The species was already found in the previous steps.
# Row 12: The species was already found in the previous steps.
# Row 13: murine
# Row 14: bovine
# Row 15: mda-mb-231
# Row 16: The species was already found in the previous steps.
# Row 17: mammalian cells
# Row 18: hela
# Row 19: The species was already found in the previous steps.
# Row 20: yeast
# Row 21: escherichia coli
# Row 22: The species was already found in the previous steps.
# Row 23: The species was already found in the previous steps.
# Row 24: tribolium castaneum
# Row 25: arabidopsis thaliana
# Row 26: fetal bovine
# Row 27: arabidopsis
# Row 28: The species was already found in the previous steps.
# Row 29: mouse
# Row 30: plankton
# Row 31: The species was already found in the previous steps.
# Row 32: p. falciparum
# Row 33: arabidopsis
# Row 34: The species was already found in the previous steps.
# Row 35: fission yeast
# Row 36: yeast
# Row 37: fetal bovine
# Row 38: h2b cells
# Row 39: fetal calf serum
# Row 40: fetal bovine
# Row 41: human fibroblasts and early mouse
# Row 42: fetal bovine
# Row 43: mouse
# Row 44: The species was already found in the previous steps.
# Row 45: sea urchin
# Row 46: The species was already found in the previous steps.
# Row 47: The species was already found in the previous steps.
# Row 48: The species was already found in the previous steps.
# Row 49: mem
# Row 50: fetal bovine
# Row 51: yeast
# Row 52: mice
# Row 53: horse
# Row 54: isogenic cancer cell lines
# Row 55: silicone elastomer
# Row 56: The species was already found in the previous steps.
# Row 57: 37¡c, 5% co2 in high-glucose dmem
# Row 58: goat
# Row 59: drosophila melanogaster
# Row 60: The species was already found in the previous steps.
# Row 61: The species was already found in the previous steps.
# Row 62: honey bees
# Row 63: yeast
# Row 64: yeast
# Row 65: fetal bovine
# Row 66: r. glauca, r. sorocarpa,
# Row 67: s. cerevisiae
# Row 68: mouse
# Row 69: mice
# Row 70: e. coli
# Row 71: homo sapiens
# Row 72: The species was already found in the previous steps.
# Row 73: bacteria
# Row 74: yeast model organism saccharomyces cerevisiae
# Row 75: mouse
# Row 76: cell lines
# Row 77: The species was already found in the previous steps.
# Row 78: The species was already found in the previous steps.
# Row 79: The species was already found in the previous steps.
# Row 80: The species was already found in the previous steps.
# Row 81: staphylococcus aureus
# Row 82: yeast
# Row 83: tlos
# Row 84: thallose liverworts
# Row 85: The species was already found in the previous steps.
# Row 86: The species was already found in the previous steps.
# Row 87: The species was already found in the previous steps.
# Row 88: The species was already found in the previous steps.
# Row 89: human
# Row 90: The species was already found in the previous steps.
# Row 91: The species was already found in the previous steps.
# Row 92: mcf-10a
# Row 93: The species was already found in the previous steps.
# Row 94: capsid-like particles
# Row 95: u-2-os cells (atcc-htb-96
# Row 96: u2os and cervical cancer hela h2b-gfp
# Row 97: reactive oxygen species (ros
# Row 98: u-2 os
# Row 99: seeded the cell pool in a single well of 384-well plate
# Row 100: The species was already found in the previous steps.
# Row 101: c57bl/6j mice
# Row 102: fetal bovine
# Row 103: The species was already found in the previous steps.
# Row 104: mouse
# Row 105: The species was already found in the previous steps.
# Row 106: The species was already found in the previous steps.
# Row 107: an embryo
# Row 108: The species was already found in the previous steps.
# Row 109: budding yeast
# Row 110: murine and human
# Row 111: The species was already found in the previous steps.
# Row 112: The species was already found in the previous steps.
# Row 113: drosophila
# Row 114: fish
# Row 115: The species was already found in the previous steps.
# Row 116: hiv-1
# Row 117: The species was already found in the previous steps.
# Row 118: xx mescs
# Row 119: metabric cohort
# Row 120: plankton
# Row 121: mice
# Row 122: The species was already found in the previous steps.
# Row 123: saccharomyces cerevisiae
# Row 124: human
# Row 125: The species was already found in the previous steps.
# Row 126: The species was already found in the previous steps.
# Row 127: fetal bovine
# Row 128: The species was already found in the previous steps.
# Row 129: The species was already found in the previous steps.
# Row 130: The species was already found in the previous steps.
# Row 131: The species was already found in the previous steps.
# Execution time: 3.14 seconds

# %%
# Creating a new column with the scientific names of the species extracted from the Species_BioBERT column
# This column will be used to store the scientific names of the species extracted from the Species_BioBERT column.
# It uses the EBI taxonomy REST API to get the scientific names of the species.
# It iterates over the Species_BioBERT column, splits the species names, and queries the EBI taxonomy REST API for each species name.
# The scientific names are stored in a list and added to the Species_Scientific_Name_BioBERT column.
# ------------------------------------------------------------

for i, item in dfs.iterrows():
    list_species = item['Species_BioBERT']
    #list_species_scientific_name = []

    if isinstance(list_species, str):
        list_species = list_species.split(', ')
        #print(list_species)

        if list_species != []:
        
            #print(list_species)
            for x in list_species:
                #print(x)

                url = f'https://www.ebi.ac.uk/ena/taxonomy/rest/any-name/{x}'
                    #print(url)

                response = requests.get(url)
                    #print(response.status_code)
                if response.status_code == 200:
                    data = response.json()
                    #print(data)
                    if data:
                        scientific_name = data[0]['scientificName']

                        #list_species_scientific_name.append(scientific_name)
                        print(f"Scientific name for {x}: {scientific_name}")

            dfs.at[i, 'Species_Scientific_Name_BioBERT'] = str(scientific_name)
        else:
            dfs.at[i, 'Species_Scientific_Name_BioBERT'] = 'Not found'
# Out:
# Scientific name for diplophyllum taxifolium: Diplophyllum taxifolium
# Scientific name for bovine: Bos taurus
# Scientific name for escherichia coli: Escherichia coli
# Scientific name for tribolium castaneum: Tribolium castaneum
# Scientific name for arabidopsis thaliana: Arabidopsis thaliana
# Scientific name for arabidopsis: Arabidopsis
# Scientific name for mouse: Mus musculus
# Scientific name for arabidopsis: Arabidopsis
# Scientific name for fission yeast: Schizosaccharomyces pombe
# Scientific name for mouse: Mus musculus
# Scientific name for sea urchin: Echinoidea
# Scientific name for mice: Mus sp.
# Scientific name for horse: Equus caballus
# Scientific name for goat: Capra hircus
# Scientific name for drosophila melanogaster: Drosophila melanogaster
# Scientific name for honey bees: Apinae
# Scientific name for mouse: Mus musculus
# Scientific name for mice: Mus sp.
# Scientific name for e. coli: Escherichia coli
# Scientific name for homo sapiens: Homo sapiens
# Scientific name for bacteria: Bacteria
# Scientific name for mouse: Mus musculus
# Scientific name for staphylococcus aureus: Staphylococcus aureus
# Scientific name for human: Homo sapiens
# Scientific name for mouse: Mus musculus
# Scientific name for drosophila: Drosophila
# Scientific name for fish: Dipnomorpha
# Scientific name for hiv-1: Human immunodeficiency virus 1
# Scientific name for mice: Mus sp.
# Scientific name for saccharomyces cerevisiae: Saccharomyces cerevisiae
# Scientific name for human: Homo sapiens

# %%
dfs['Species_Scientific_Name_BioBERT'] = dfs['Species_Scientific_Name_BioBERT'].astype(str)

# %%
dfs
# Out:
#      Unnamed: 0 Comment[IDR_Study_Accession]  \
# 0             0                      idr0092
# 1             1                      idr0016
# 2             2                      idr0079
# 3             3                      idr0067
# 4             4                      idr0134
# ..          ...                          ...
# 127         127                      idr0023
# 128         128                      idr0038
# 129         129                      idr0138
# 130         130                      idr0128
# 131         131                      idr0123
#
#                                            Study_Title  \
# 0    a semi-automated organoid screening method dem...
# 1    human u2os cells - compound cell-painting expe...
# 2    an image-based data-driven analysis of cellula...
# 3    meiotic cellular rejuvenation is coupled to nu...
# 4    reference bioimaging dataset to assess the phe...
# ..                                                 ...
# 127  nuclear pore scaffold structure analyzed by su...
# 128  ex vivo live cell tracking in kidney organoids...
# 129  integration of spatial and single-cell transcr...
# 130  parallel compound screen for infection modulat...
# 131  simultaneous visualization of dna loci in sing...
#
#                              Study_Type Study_Type_Term_Source_REF  \
# 0               compound library screen                        efo
# 1                   high content screen                        efo
# 2                      microscopy assay                        efo
# 3                    time-lapse imaging                       omit
# 4                             histology                       none
# ..                                  ...                        ...
# 127                protein localization                        efo
# 128                  time-lapse imaging                       omit
# 129                             seqfish                        efo
# 130                 high content screen                        efo
# 131  fluorescence in situ hybridization                       ncit
#
#     Study_Type_Term_Accession  \
# 0                 efo_0007553
# 1                 efo_0007550
# 2                 efo_0002909
# 3                omit_0027490
# 4                        none
# ..                        ...
# 127                go:0008104
# 128              omit_0027490
# 129               efo_0008991
# 130               efo_0007550
# 131               ncit_c17563
#
#                                      Study_Description  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                         Study_Key_Words              Study_Organism  \
# 0                             organoids                mus musculus
# 1                                   NaN                homo sapiens
# 2                        image analysis                 danio rerio
# 3                               meiosis  saccharomyces cerevisiae\n
# 4                            phenotypes       diplophyllum albicans
# ..                                  ...                         ...
# 127                                 NaN                homo sapiens
# 128                                 NaN                mus musculus
# 129                             seqfish                mus musculus
# 130                   influenza a virus                homo sapiens
# 131  fluorescence in situ hybridization                homo sapiens
#
#     Study_Organism_Term_Source_REF  ...  \
# 0                        ncbitaxon  ...
# 1                        ncbitaxon  ...
# 2                        ncbitaxon  ...
# 3                        ncbitaxon  ...
# 4                        ncbitaxon  ...
# ..                             ...  ...
# 127                      ncbitaxon  ...
# 128                      ncbitaxon  ...
# 129                      ncbitaxon  ...
# 130                      ncbitaxon  ...
# 131                      ncbitaxon  ...
#
#                       Study_Description_clean_entities  \
# 0    [intestinal, model study, epithelial biology, ...
# 1    [phenotypic profiling, multiparametric analysi...
# 2    [morphology, intracellular, organization, zebr...
# 3    [production, healthy, meiosis, quality, distri...
# 4    [dataset, macroscopic, phenotypic property spe...
# ..                                                 ...
# 127  [lifes, molecular machinery, protein assembly,...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [molecular profiling, single cell advance, dis...
# 130  [viral infectious disease, immunosuppression, ...
# 131  [dataset, ifish, pipeline, small size, kilobas...
#
#                 Experiment_Description_clean_lemmatize  \
# 0                                                  NaN
# 1                                                  NaN
# 2    confocal imaging fixed sample zebrafish poster...
# 3    fix cell fluorescence microscopy transmission ...
# 4    representative voucher specimen receive herbar...
# ..                                                 ...
# 127  systematic immunolabelling complex monomeric e...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  seqfish study sagittal section mouse embryo so...
# 130                                                NaN
# 131  dataset replicate experimental design consist ...
#
#                  Experiment_Description_clean_entities  \
# 0                                                   []
# 1                                                   []
# 2    [confocal imaging, posterior lateral line, pri...
# 3    [cell fluorescence microscopy, image, yeast, m...
# 4    [specimen, herbaria, sample diplophyllum taxif...
# ..                                                 ...
# 127  [systematic immunolabelling, complex, monomeri...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [seqfish study, sagittal section, mouse, embry...
# 130                                                 []
# 131  [dataset, replicate, experimental design, prob...
#
#                                   Description_combined  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                                         Entities_SpaCy  \
# 0    {'CANCER': ['intestinal organoids', 'intestina...
# 1    {'CELL': ['cellular', 'u2os cells', 'cell', 'c...
# 2    {'CELL': ['cell', 'single-cell', 'cell', 'cell...
# 3    {'CELLULAR_COMPONENT': ['nuclear', 'nuclear', ...
# 4                                                   {}
# ..                                                 ...
# 127  {'CELLULAR_COMPONENT': ['nuclear', 'pores'], '...
# 128  {'ORGANISM': ['mouse kidney rudiment', 'e13.5 ...
# 129  {'CELL': ['cells', 'cells', 'single-cell', 'si...
# 130  {'CANCER': ['cancer'], 'ORGAN': ['organ'], 'OR...
# 131  {'CELLULAR_COMPONENT': ['dna', 'chromosome con...
#
#                                         Species_SpaCy  \
# 0                                           Not found
# 1                                           Not found
# 2       [zebrafish posterior lateral line primordium]
# 3                                           Not found
# 4                                           Not found
# ..                                                ...
# 127                                         Not found
# 128  [mouse kidney rudiment, e13.5 embryonic kidneys]
# 129                                   [mouse embryos]
# 130   [human, human rhinovirus, herpes simplex virus]
# 131                                     [human cells]
#
#                       Species_Scientific_Name_SciSpacy Specie_found_Scispacy  \
# 0                                                   []                    No
# 1                                                   []                    No
# 2                                      ['Danio rerio']                   Yes
# 3                                                   []                    No
# 4                                                   []                    No
# ..                                                 ...                   ...
# 127                                                 []                    No
# 128                                   ['Mus musculus']                   Yes
# 129                                   ['Mus musculus']                   Yes
# 130  ['Homo sapiens', 'Homo sapiens', 'Enterovirus'...                   Yes
# 131                                   ['Homo sapiens']                   Yes
#
#                            Species_BioBERT Species_Scientific_Name_BioBERT
# 0    small intestinal crypts were isolated                       Not found
# 1                                     u2os                       Not found
# 2                                      NaN                             NaN
# 3                            budding yeast                       Not found
# 4                  diplophyllum taxifolium         Diplophyllum taxifolium
# ..                                     ...                             ...
# 127                           fetal bovine                    Homo sapiens
# 128                                    NaN                             NaN
# 129                                    NaN                             NaN
# 130                                    NaN                             NaN
# 131                                    NaN                             NaN
#
# [132 rows x 238 columns]

# %%
dfs['Species_Scientific_Name_BioBERT'][4] == 'Homo sapiens'
# Out:
# False

# %%
for i, item in dfs.iterrows():
    specie_found = item['Specie_found_Scispacy']

    if specie_found.startswith("No"):

        if isinstance(item['Study_Organism'], str) and item['Study_Organism'].strip() != '':
            real_specie = item['Study_Organism'][0]
            bert_specie = item['Species_Scientific_Name_BioBERT'][0]
            clean_biobert_specie = remove_special_characters(bert_specie).lower()

            if real_specie in clean_biobert_specie:

                print('The real species is in the bert')
                dfs.at[i, 'Specie_found_biobert'] = 'Yes'
            else:
                print('The real species is NOT in the response.')
                dfs.at[i, 'Specie_found_biobert'] = 'No'
        else:
            print('No real species to check in the response.')
            dfs.at[i, 'Specie_found_biobert'] = 'No species provided'
# Out:
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# No real species to check in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is NOT in the response.
# The real species is NOT in the response.
# No real species to check in the response.
# The real species is NOT in the response.
# The real species is NOT in the response.
# The real species is in the bert
# The real species is NOT in the response.
# The real species is in the bert
# The real species is NOT in the response.
# No real species to check in the response.
# The real species is in the bert
# The real species is in the bert
# The real species is in the bert

# %%
dfs['Specie_found_biobert'].value_counts()
# Out:
# Specie_found_biobert
# No                     46
# Yes                    34
# No species provided     3
# Name: count, dtype: int64

# %%
type(dfs['Specie_found_biobert'][2])
# Out:
# float

# %%
dfs
# Out:
#      Unnamed: 0 Comment[IDR_Study_Accession]  \
# 0             0                      idr0092
# 1             1                      idr0016
# 2             2                      idr0079
# 3             3                      idr0067
# 4             4                      idr0134
# ..          ...                          ...
# 127         127                      idr0023
# 128         128                      idr0038
# 129         129                      idr0138
# 130         130                      idr0128
# 131         131                      idr0123
#
#                                            Study_Title  \
# 0    a semi-automated organoid screening method dem...
# 1    human u2os cells - compound cell-painting expe...
# 2    an image-based data-driven analysis of cellula...
# 3    meiotic cellular rejuvenation is coupled to nu...
# 4    reference bioimaging dataset to assess the phe...
# ..                                                 ...
# 127  nuclear pore scaffold structure analyzed by su...
# 128  ex vivo live cell tracking in kidney organoids...
# 129  integration of spatial and single-cell transcr...
# 130  parallel compound screen for infection modulat...
# 131  simultaneous visualization of dna loci in sing...
#
#                              Study_Type Study_Type_Term_Source_REF  \
# 0               compound library screen                        efo
# 1                   high content screen                        efo
# 2                      microscopy assay                        efo
# 3                    time-lapse imaging                       omit
# 4                             histology                       none
# ..                                  ...                        ...
# 127                protein localization                        efo
# 128                  time-lapse imaging                       omit
# 129                             seqfish                        efo
# 130                 high content screen                        efo
# 131  fluorescence in situ hybridization                       ncit
#
#     Study_Type_Term_Accession  \
# 0                 efo_0007553
# 1                 efo_0007550
# 2                 efo_0002909
# 3                omit_0027490
# 4                        none
# ..                        ...
# 127                go:0008104
# 128              omit_0027490
# 129               efo_0008991
# 130               efo_0007550
# 131               ncit_c17563
#
#                                      Study_Description  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                         Study_Key_Words              Study_Organism  \
# 0                             organoids                mus musculus
# 1                                   NaN                homo sapiens
# 2                        image analysis                 danio rerio
# 3                               meiosis  saccharomyces cerevisiae\n
# 4                            phenotypes       diplophyllum albicans
# ..                                  ...                         ...
# 127                                 NaN                homo sapiens
# 128                                 NaN                mus musculus
# 129                             seqfish                mus musculus
# 130                   influenza a virus                homo sapiens
# 131  fluorescence in situ hybridization                homo sapiens
#
#     Study_Organism_Term_Source_REF  ...  \
# 0                        ncbitaxon  ...
# 1                        ncbitaxon  ...
# 2                        ncbitaxon  ...
# 3                        ncbitaxon  ...
# 4                        ncbitaxon  ...
# ..                             ...  ...
# 127                      ncbitaxon  ...
# 128                      ncbitaxon  ...
# 129                      ncbitaxon  ...
# 130                      ncbitaxon  ...
# 131                      ncbitaxon  ...
#
#                 Experiment_Description_clean_lemmatize  \
# 0                                                  NaN
# 1                                                  NaN
# 2    confocal imaging fixed sample zebrafish poster...
# 3    fix cell fluorescence microscopy transmission ...
# 4    representative voucher specimen receive herbar...
# ..                                                 ...
# 127  systematic immunolabelling complex monomeric e...
# 128  adapt mouse kidney rudiment assay generate ren...
# 129  seqfish study sagittal section mouse embryo so...
# 130                                                NaN
# 131  dataset replicate experimental design consist ...
#
#                  Experiment_Description_clean_entities  \
# 0                                                   []
# 1                                                   []
# 2    [confocal imaging, posterior lateral line, pri...
# 3    [cell fluorescence microscopy, image, yeast, m...
# 4    [specimen, herbaria, sample diplophyllum taxif...
# ..                                                 ...
# 127  [systematic immunolabelling, complex, monomeri...
# 128  [adapt, mouse kidney rudiment assay, renal org...
# 129  [seqfish study, sagittal section, mouse, embry...
# 130                                                 []
# 131  [dataset, replicate, experimental design, prob...
#
#                                   Description_combined  \
# 0    intestinal organoids are an excellent model to...
# 1    phenotypic profiling attempts to summarize mul...
# 2    a data-driven analysis of cell morphology and ...
# 3    production of healthy gametes in meiosis relie...
# 4    here, we present a high-quality reference data...
# ..                                                 ...
# 127  much of life's essential molecular machinery c...
# 128  we have adapted the mouse kidney rudiment assa...
# 129  molecular profiling of single cells has advanc...
# 130  viral infectious diseases span a myriad of mal...
# 131  we describe a dataset obtained by applying our...
#
#                                         Entities_SpaCy  \
# 0    {'CANCER': ['intestinal organoids', 'intestina...
# 1    {'CELL': ['cellular', 'u2os cells', 'cell', 'c...
# 2    {'CELL': ['cell', 'single-cell', 'cell', 'cell...
# 3    {'CELLULAR_COMPONENT': ['nuclear', 'nuclear', ...
# 4                                                   {}
# ..                                                 ...
# 127  {'CELLULAR_COMPONENT': ['nuclear', 'pores'], '...
# 128  {'ORGANISM': ['mouse kidney rudiment', 'e13.5 ...
# 129  {'CELL': ['cells', 'cells', 'single-cell', 'si...
# 130  {'CANCER': ['cancer'], 'ORGAN': ['organ'], 'OR...
# 131  {'CELLULAR_COMPONENT': ['dna', 'chromosome con...
#
#                                         Species_SpaCy  \
# 0                                           Not found
# 1                                           Not found
# 2       [zebrafish posterior lateral line primordium]
# 3                                           Not found
# 4                                           Not found
# ..                                                ...
# 127                                         Not found
# 128  [mouse kidney rudiment, e13.5 embryonic kidneys]
# 129                                   [mouse embryos]
# 130   [human, human rhinovirus, herpes simplex virus]
# 131                                     [human cells]
#
#                       Species_Scientific_Name_SciSpacy Specie_found_Scispacy  \
# 0                                                   []                    No
# 1                                                   []                    No
# 2                                      ['Danio rerio']                   Yes
# 3                                                   []                    No
# 4                                                   []                    No
# ..                                                 ...                   ...
# 127                                                 []                    No
# 128                                   ['Mus musculus']                   Yes
# 129                                   ['Mus musculus']                   Yes
# 130  ['Homo sapiens', 'Homo sapiens', 'Enterovirus'...                   Yes
# 131                                   ['Homo sapiens']                   Yes
#
#                            Species_BioBERT Species_Scientific_Name_BioBERT  \
# 0    small intestinal crypts were isolated                       Not found
# 1                                     u2os                       Not found
# 2                                      NaN                             NaN
# 3                            budding yeast                       Not found
# 4                  diplophyllum taxifolium         Diplophyllum taxifolium
# ..                                     ...                             ...
# 127                           fetal bovine                    Homo sapiens
# 128                                    NaN                             NaN
# 129                                    NaN                             NaN
# 130                                    NaN                             NaN
# 131                                    NaN                             NaN
#
#     Specie_found_biobert
# 0                     No
# 1                     No
# 2                    NaN
# 3                     No
# 4                    Yes
# ..                   ...
# 127                  Yes
# 128                  NaN
# 129                  NaN
# 130                  NaN
# 131                  NaN
#
# [132 rows x 239 columns]

# %%
#model_id = "meta-llama/Llama-3.2-3B-Instruct"
model_id = "mistralai/Mistral-7B-Instruct-v0.3"

pipe = pipeline("text-generation",
                model = model_id,
                torch_dtype = torch.bfloat16,
                device_map="auto",
                pad_token_id=128001 
               )
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2302, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2301 try:
# -> 2302     tokenizer = cls(*init_inputs, **init_kwargs)
#    2303 except import_protobuf_decode_error():
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/llama/tokenization_llama_fast.py:157, in LlamaTokenizerFast.__init__(self, vocab_file, tokenizer_file, clean_up_tokenization_spaces, unk_token, bos_token, eos_token, add_bos_token, add_eos_token, use_default_system_prompt, legacy, add_prefix_space, **kwargs)
#     155     kwargs["from_slow"] = True
# --> 157 super().__init__(
#     158     vocab_file=vocab_file,
#     159     tokenizer_file=tokenizer_file,
#     160     clean_up_tokenization_spaces=clean_up_tokenization_spaces,
#     161     unk_token=unk_token,
#     162     bos_token=bos_token,
#     163     eos_token=eos_token,
#     164     add_bos_token=add_bos_token,
#     165     add_eos_token=add_eos_token,
#     166     use_default_system_prompt=use_default_system_prompt,
#     167     add_prefix_space=add_prefix_space,
#     168     legacy=legacy,
#     169     **kwargs,
#     170 )
#     171 self._add_bos_token = add_bos_token
#
# File /opt/conda/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:108, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     107 if from_slow and slow_tokenizer is None and self.slow_tokenizer_class is None:
# --> 108     raise ValueError(
#     109         "Cannot instantiate this tokenizer from a slow version. If it's based on sentencepiece, make sure you "
#     110         "have sentencepiece installed."
#     111     )
#     113 if tokenizer_object is not None:
#
# ValueError: Cannot instantiate this tokenizer from a slow version. If it's based on sentencepiece, make sure you have sentencepiece installed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 4
#       1 #model_id = "meta-llama/Llama-3.2-3B-Instruct"
#       2 model_id = "mistralai/Mistral-7B-Instruct-v0.3"
# ----> 4 pipe = pipeline("text-generation",
#       5                 model = model_id,
#       6                 torch_dtype = torch.bfloat16,
#       7                 device_map="auto",
#       8                 pad_token_id=128001
#       9                )
#
# File /opt/conda/lib/python3.11/site-packages/transformers/pipelines/__init__.py:1049, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1046             tokenizer_kwargs = model_kwargs.copy()
#    1047             tokenizer_kwargs.pop("torch_dtype", None)
# -> 1049         tokenizer = AutoTokenizer.from_pretrained(
#    1050             tokenizer_identifier, use_fast=use_fast, _from_pipeline=task, **hub_kwargs, **tokenizer_kwargs
#    1051         )
#    1053 if load_image_processor:
#    1054     # Try to infer image processor from model or config name (if provided as str)
#    1055     if image_processor is None:
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:1009, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1005     if tokenizer_class is None:
#    1006         raise ValueError(
#    1007             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#    1008         )
# -> 1009     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1011 # Otherwise we have to be creative.
#    1012 # if model is an encoder decoder, the encoder tokenizer class is used by default
#    1013 if isinstance(config, EncoderDecoderConfig):
#
# File /opt/conda/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2062, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2059     else:
#    2060         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2062 return cls._from_pretrained(
#    2063     resolved_vocab_files,
#    2064     pretrained_model_name_or_path,
#    2065     init_configuration,
#    2066     *init_inputs,
#    2067     token=token,
#    2068     cache_dir=cache_dir,
#    2069     local_files_only=local_files_only,
#    2070     _commit_hash=commit_hash,
#    2071     _is_local=is_local,
#    2072     trust_remote_code=trust_remote_code,
#    2073     **kwargs,
#    2074 )
#
# File /opt/conda/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2303, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2301 try:
#    2302     tokenizer = cls(*init_inputs, **init_kwargs)
# -> 2303 except import_protobuf_decode_error():
#    2304     logger.info(
#    2305         "Unable to load tokenizer model from SPM, loading from TikToken will be attempted instead."
#    2306         "(Google protobuf error: Tried to load SPM model with non-SPM vocab file).",
#    2307     )
#    2308     return False
#
# File /opt/conda/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:87, in import_protobuf_decode_error(error_message)
#      85     return DecodeError
#      86 else:
# ---> 87     raise ImportError(PROTOBUF_IMPORT_ERROR.format(error_message))
#
# ImportError:
#  requires the protobuf library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/protocolbuffers/protobuf/tree/master/python#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.

# %%
start_time = time.time()
for row, i in dfs.iterrows():
    value_biobert = str(i['Specie_found_biobert'])
    
    if value_biobert.startswith("No"):
    
        message = [
        {"role": "system", "content": i["Description_combined"]},
        {"role": "user", "content": "Can you tell me which scientific species was used in this study?"},
        ]

        outputs = pipe(message, max_new_tokens = 256)
        response = outputs[0]["generated_text"][-1]["content"]
        clean_response = remove_special_characters(response).lower()
        
        dfs.at[row, 'Species_Mistral'] = clean_response
        print(f"Processed row {row} for species extraction.")

        if isinstance(i['Study_Organism'], str) and i['Study_Organism'].strip() != '':

            real_specie = i['Study_Organism'][0]

            if real_specie in clean_response:
                print('The real species is in the response.')
                dfs.at[row, 'Species_found_Mistral'] = 'Yes'
            else:
                print('The real species is NOT in the response.')
                dfs.at[row, 'Species_found_Mistral'] = 'No'
        else:
            print('No real species to check in the response.')
            dfs.at[row, 'Species_found_Mistral'] = 'No species provided'

# %%
dfs['Species_found_Mistral'].value_counts()

# %%
start_time = time.time()
for row, i in dfs.iterrows():
    value_biobert = str(i['Specie_found_biobert'])

    if value_biobert.startswith("No"):
    
        message = [
        {"role": "system", "content": i["Description_combined"]},
        {"role": "user", "content": "Can you tell me which scientific species was used in this study?"},
        ]

        outputs = pipe(message, max_new_tokens = 256)
        response = outputs[0]["generated_text"][-1]["content"]
        clean_response = remove_special_characters(response).lower()
        
        dfs.at[row, 'Species_Llama'] = clean_response
        print(f"Processed row {row} for species extraction.")

        if isinstance(i['Study_Organism'], str) and i['Study_Organism'].strip() != '':

            real_specie = i['Study_Organism'][0]

            if real_specie in clean_response:
                print('The real species is in the response.')
                dfs.at[row, 'Species_found_Llama'] = 'Yes'
            else:
                print('The real species is NOT in the response.')
                dfs.at[row, 'Species_found_Llama'] = 'No'
        else:
            print('No real species to check in the response.')
            dfs.at[row, 'Species_found_Llama'] = 'No species provided'


end_time = time.time()

print(f"Execution time: {end_time - start_time:.2f} seconds")
# Out:
# Processed row 0 for species extraction.
# The real species is in the response.
# Processed row 1 for species extraction.
# The real species is in the response.
# Processed row 3 for species extraction.
# The real species is in the response.
# Processed row 6 for species extraction.
# The real species is in the response.
# Processed row 8 for species extraction.
# The real species is in the response.
# Processed row 13 for species extraction.
# The real species is in the response.
# Processed row 14 for species extraction.
# The real species is in the response.
# Processed row 15 for species extraction.
# The real species is in the response.
# Processed row 17 for species extraction.
# The real species is in the response.
# Processed row 18 for species extraction.
# The real species is in the response.
# Processed row 20 for species extraction.
# The real species is in the response.
# Processed row 26 for species extraction.
# The real species is in the response.
# Processed row 32 for species extraction.
# The real species is in the response.
# Processed row 37 for species extraction.
# The real species is in the response.
# Processed row 38 for species extraction.
# The real species is in the response.
# Processed row 39 for species extraction.
# The real species is in the response.
# Processed row 40 for species extraction.
# The real species is in the response.
# Processed row 41 for species extraction.
# The real species is in the response.
# Processed row 42 for species extraction.
# The real species is in the response.
# Processed row 45 for species extraction.
# The real species is in the response.
# Processed row 49 for species extraction.
# The real species is in the response.
# Processed row 50 for species extraction.
# The real species is in the response.
# Processed row 51 for species extraction.
# The real species is in the response.
# Processed row 53 for species extraction.
# The real species is in the response.
# Processed row 54 for species extraction.
# The real species is in the response.
# Processed row 55 for species extraction.
# The real species is in the response.
# Processed row 57 for species extraction.
# The real species is in the response.
# Processed row 58 for species extraction.
# The real species is in the response.
# Processed row 63 for species extraction.
# The real species is in the response.
# Processed row 64 for species extraction.
# The real species is in the response.
# Processed row 65 for species extraction.
# The real species is in the response.
# Processed row 66 for species extraction.
# The real species is in the response.
# Processed row 67 for species extraction.
# The real species is in the response.
# Processed row 68 for species extraction.
# No real species to check in the response.
# Processed row 73 for species extraction.
# The real species is in the response.
# Processed row 74 for species extraction.
# The real species is in the response.
# Processed row 76 for species extraction.
# The real species is in the response.
# Processed row 83 for species extraction.
# The real species is in the response.
# Processed row 84 for species extraction.
# The real species is in the response.
# Processed row 96 for species extraction.
# The real species is in the response.
# Processed row 101 for species extraction.
# The real species is in the response.
# Processed row 107 for species extraction.
# The real species is in the response.
# Processed row 109 for species extraction.
# The real species is in the response.
# Processed row 110 for species extraction.
# No real species to check in the response.
# Processed row 113 for species extraction.
# The real species is in the response.
# Processed row 114 for species extraction.
# The real species is in the response.
# Processed row 118 for species extraction.
# The real species is in the response.
# Processed row 120 for species extraction.
# The real species is in the response.
# Processed row 121 for species extraction.
# No real species to check in the response.
# Execution time: 67.30 seconds

# %%
dfs['Species_found_Llama'].value_counts()
# Out:
# Species_found_Llama
# Yes                    46
# No species provided     3
# Name: count, dtype: int64

# %%
#dfs = dfs.rename(columns = {"Species_found_Llama":"Species_found_Mistral" })

# %%
for row, i in dfs.iterrows():
    value_scipacy = str(i['Specie_found_biobert'])
    print(value_scipacy)
    
    value_biobert = str(i['Specie_found_Scispacy'])
    print(value_biobert)
    
    value_mistral = str(i['Species_found_Mistral'])
    print(value_mistral)
    
    value_llama = str(i['Species_found_Llama'])
    print(value_llama)

    if value_scipacy.startswith("Yes") or value_biobert.startswith("Yes") or value_lama.startswith("Yes"):
        print(f"Row {row}: Species found in one of the methods.")
        dfs.at[row, 'Species_found'] = 'Yes'

    else:
        print(f"Row {row}: Species not found in any method.")
        dfs.at[row, 'Species_found'] = 'No'

# %%
dfs['Species_found'].value_counts()

# %%
count_spacy = 0
count_biobert = 0
count_mistral = 0 
count_llama = 0

for row, i in dfs.iterrows():
    value_scipacy = str(i['Specie_found_Scispacy'])
    if value_scipacy.startswith("Yes") :
        count_spacy +=1
        
    value_biobert = str(i['Specie_found_biobert'])
    if value_biobert.startswith("Yes") :
        count_biobert +=1
    
    value_mistral = str(i['Species_found_Mistral'])
    if value_mistral.startswith("Yes") :
        count_mistral +=1
    
    value_llama = str(i['Species_found_Llama'])
    if value_llama.startswith("Yes") :
        count_llama +=1

print(f'Count spacy: {count_spacy}; Count biobert: {count_biobert}; Count Mistral: {count_mistral}; Count Llama {count_llama}')

# %%
for row, i in dfs.iterrows():
    value_scipacy = str(i['Specie_found_biobert'])
    value_biobert = i['Specie_found_Scispacy']
    value_lama = i['Species_found_Llama']
    value_mistral = i['Species_found_Mistral']

    if value_scipacy.startswith("Yes") :
        print(f"Row {row}: Species found in SciSpacy, but not in BioBERT.") ## I am not sure about this

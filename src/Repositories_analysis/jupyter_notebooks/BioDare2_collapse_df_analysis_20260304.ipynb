# %%
import pandas as pd
import requests 
import json
import os
#import networkx as nx

import matplotlib.pyplot as plt
#from wordcloud import WordCloud

from collections import defaultdict
import spacy
#import Functions as fn
#import seaborn as sns
import numpy as np  
#from fitter import Fitter
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nlp = spacy.load("en_core_sci_sm")
# Out:
# /opt/conda/lib/python3.11/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
pwd
# Out:
# '/home/eidf128/eidf128/shared/export/juliana/export/juliana'

# %%
home_dir = '/home/eidf128/eidf128/shared/export/juliana/export/juliana'

# %% [markdown]
# ### Functions

# %% [markdown]
# ##### Cleaning

# %%
def remove_stop_words(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words("english"))
    filtered = [w for w in tokens if w.lower() not in stop_words and w.isalpha()]

    return filtered

# %%
def remove_special_characters(text):
    """
    This function removes special characters from the text.
    :param text: text
    :return: text without special characters
    """
    cleaned_string = re.sub(r'[?|$|.|!|@|#|%|^|&|*|(|)|-|_|+|=|;|:|,|<|>|/|{|}|[|]|~|`|\'|\"|\\]',r'', text)

    return cleaned_string

# %%
def clean_text(text):
    if pd.isna(text) or str(text).strip() == "":
        return ""
    text = remove_special_characters(str(text)) or ""
    
    return remove_stop_words(text)

# %% [markdown]
# ##### NLP

# %%
# It lemmizes a text
def lemmatizer(phrase):
    """
    This function lemmatizes a text.
    :param phrase: text

    :return: the lemmatized text
    """
    doc = nlp(phrase)
    lemmatized_tokens = [token.lemma_ for token in doc]
    lemmatized_text = ' '.join(lemmatized_tokens)
    
    return lemmatized_text

# %%
# It extracts the entities from a text
def entities_recognition(phrase):
    """
    This function extracts the entities from a text.
    :param phrase: text
    :return: the entities extracted from the text
    """
    entities = []
    doc_phrase = nlp(phrase)
    entities = list(doc_phrase.ents)
    
    return entities

# %%
def entities_concatenated(list_dfs,title):
    """
    This function concatenates the entities extracted from a list columns names given as parameter of a list of dataframes.
    :param list_dfs: list of dataframes
    :param title: new column name

    :return: the list of dataframes with the entities concatenated in a new column
    """
    count = 0
    while count < len(list_dfs):
        wk_df = list_dfs[count]
        list1 = wk_df["dc.description.abstract_entities_recognised_after_lemmatizer_and_splitting"]
        
        concatenated_list = list1 
        wk_df[title] = concatenated_list

        count += 1
        
    return list_dfs

# %%
# It counts the number of words in a phrase
def count_words(phrase):
    """
    This function counts the number of words in a phrase.
    :param phrase: text

    :return: the number of words in the phrase
    """
    lenght = 0
    if len(phrase) > 1 and phrase.isspace() == True:
        lenght = 1
    
    else:
        words = phrase.split()
        lenght = len(words)
    
    return lenght

# %%
# It counts the number of characters in a phrase
def count_characters(phrase):
    """
    This function counts the number of characters in a phrase.
    :param phrase: text

    :return: the number of characters in the phrase
    """
    lenght = 0
    if len(phrase) < 1:
        lenght = 0
    else:
        lenght = len(phrase)
        
    return lenght

# %%
def first_non_null(s):
    s = s.dropna()
    return s.iloc[0] if len(s) else pd.NA

# %%
def join_unique_non_null(s, sep=" | "):
    s = s.dropna().astype(str)
    s = s[s.str.strip().ne("")]           # drop empty strings
    s = pd.unique(s)                      # keep unique (preserve order)
    return sep.join(s) if len(s) else pd.NA

# %%
def to_text(x):
    # missing
    if x is None or (isinstance(x, float) and pd.isna(x)):
        return ""
    # already a string
    if isinstance(x, str):
        return x
    # list/tuple/set/np array of tokens
    if isinstance(x, (list, tuple, set, np.ndarray)):
        return " ".join(map(str, x))
    # fallback: convert whatever it is to string
    return str(x)

# %% [markdown]
# ## BioDare2

# %%
data_dir = '/home/eidf128/eidf128/shared/export/juliana/export/juliana/BioDare_metadata_20250722'

# %%
os.chdir(data_dir)

# %%
files = [f for f in os.listdir(data_dir) if f.endswith('.json')]
len(files)
# Out:
# 20471

# %%
df_biodare2 = pd.DataFrame()
dfs = []
for file in files:
    temp_df = pd.read_json(file)
    dfs.append(temp_df)
    
df_biodare2 = pd.concat(dfs, ignore_index=True, sort=False)

# %%
df_biodare2
# Out:
#            id versionId                                        generalDesc  \
# 0       20080    56.0.2                   Testing rhythmicity in organoids
# 1       20080    56.0.2  Validation of circadian rhythmicity in organoi...
# 2       20080    56.0.2                                                NaN
# 3       20080    56.0.2  Automatically published by BioDare2 system on ...
# 4       20080    56.0.2                                                NaN
# ...       ...       ...                                                ...
# 798224  30684     2.0.2                                                NaN
# 798225  30684     2.0.2                                                NaN
# 798226  30684     2.0.2                                                NaN
# 798227  30684     2.0.2                                                NaN
# 798228  30684     2.0.2                                                NaN
#
#                                          contributionDesc experimentalDetails  \
# 0                                                     NaN                 NaN
# 1                                                     NaN                 NaN
# 2                                                     NaN                 NaN
# 3                                                     NaN                 NaN
# 4       [{'id': 2734, 'login': 'sungkook.chun', 'first...                 NaN
# ...                                                   ...                 ...
# 798224                                                NaN                 NaN
# 798225                                                NaN                 NaN
# 798226                                                NaN                 NaN
# 798227                                                NaN                 NaN
# 798228                                                NaN                 NaN
#
#        characteristic bioDescription bioSummary       species   dataCategory  \
# 0                 NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 1                 NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 2                 NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 3                 NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 4                 NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# ...               ...            ...        ...           ...            ...
# 798224            NaN            NaN         []  Homo sapiens  EXPR_REPORTER
# 798225            NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 798226            NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 798227            NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
# 798228            NaN            NaN        NaN  Homo sapiens  EXPR_REPORTER
#
#                                    provenance
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 798224                                    NaN
# 798225  [2024, 12, 19, 11, 19, 24, 801612438]
# 798226                              Loïc Metz
# 798227  [2024, 12, 19, 11, 23, 16, 404619841]
# 798228                              Loïc Metz
#
# [798229 rows x 11 columns]

# %%
df_biodare2.columns
# Out:
# Index(['id', 'versionId', 'generalDesc', 'contributionDesc',
#        'experimentalDetails', 'characteristic', 'bioDescription', 'bioSummary',
#        'species', 'dataCategory', 'provenance'],
#       dtype='str')

# %%
df_biodare2_collapsed = (
    df_biodare2.groupby("id", as_index=False)
      .agg({
          "versionId": first_non_null,
          ""
          "generalDesc": join_unique_non_null,   # combine all descriptions
          "contributionDesc": first_non_null,
          "experimentalDetails": first_non_null,
          "characteristic": first_non_null,
          "bioDescription": first_non_null,
          "bioSummary": first_non_null,
          "species": first_non_null,
          "dataCategory": first_non_null,
          "provenance": first_non_null,
      })
)

df_biodare2_clean = pd.DataFrame(df_biodare2_collapsed)

# %%
type(df_biodare2_clean)
# Out:
# pandas.DataFrame

# %%
df_biodare2_clean
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      Controls | Global Search | null\nGrowth condit...
# 1      TiMet WP1.1 qRT-PCR elf3 LD | TiMet focuses on...
# 2      Q-PCR LD (12:12) 17C LHY | Experiment to repar...
# 3      cca1 lhy Long #1 CCA1 marker | Test for period...
# 4      cca1 lhy Long #1 CAB2 marker | Test for period...
# ...                                                  ...
# 20466  Niwa et al. (2007); GI, FKF1, CDF1, CO, FT mRN...
# 20467  AT0053:  4x3:21-LL | photoperiod alteration st...
# 20468  Analysis of Control Strains Neurospora crassa ...
# 20469  030810H3 SD-LD | Re-entrainment dynamics durin...
# 20470  SDtoLD 260410 | Re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': None, 'login': None, 'firstName': 'Fel...
# 1      [{'id': None, 'login': None, 'firstName': 'Ann...
# 2      [{'id': None, 'login': None, 'firstName': 'Aur...
# 3      [{'id': None, 'login': None, 'firstName': 'Vic...
# 4      [{'id': None, 'login': None, 'firstName': 'Vic...
# ...                                                  ...
# 20466  [{'id': None, 'login': None, 'firstName': 'Niw...
# 20467  [{'id': None, 'login': None, 'firstName': 'Adr...
# 20468  [{'id': None, 'login': None, 'firstName': 'Fel...
# 20469  [{'id': None, 'login': None, 'firstName': 'Sar...
# 20470  [{'id': None, 'login': None, 'firstName': 'Lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'Luciferase luminescence', 'equi...          False
# 1      {'technique': 'RT-PCR', 'equipment': 'PerkinEl...          False
# 2      {'technique': 'qRT-PCR', 'equipment': 'Robot +...          False
# 3      {'technique': 'Luciferase luminescence', 'equi...          False
# 4      {'technique': 'Luciferase luminescence', 'equi...          False
# ...                                                  ...            ...
# 20466  {'technique': 'RT-PCR', 'equipment': None, 'de...          False
# 20467  {'technique': 'Luciferase luminescence', 'equi...          False
# 20468  {'technique': 'Luciferase luminescence', 'equi...          False
# 20469  {'technique': 'Luciferase luminescence', 'equi...          False
# 20470  {'technique': 'Luciferase luminescence', 'equi...          False
#
#       bioDescription bioSummary               species   dataCategory  \
# 0                 []         []     Neurospora crassa    GEN_IMAGING
# 1                 []         []  Arabidopsis thaliana     TRANSCRIPT
# 2                 []         []  Arabidopsis thaliana     TRANSCRIPT
# 3                 []         []  Arabidopsis thaliana  EXPR_REPORTER
# 4                 []         []  Arabidopsis thaliana  EXPR_REPORTER
# ...              ...        ...                   ...            ...
# 20466             []         []  Arabidopsis thaliana     TRANSCRIPT
# 20467             []         []  Arabidopsis thaliana  EXPR_REPORTER
# 20468             []         []     Neurospora crassa    GEN_IMAGING
# 20469             []         []  Arabidopsis thaliana  EXPR_REPORTER
# 20470             []         []    Ostreococcus tauri    GEN_IMAGING
#
#                       provenance
# 0           [2014, 5, 5, 12, 40]
# 1      [2015, 2, 22, 18, 47, 37]
# 2         [2015, 9, 4, 1, 21, 5]
# 3      [2015, 10, 27, 20, 2, 45]
# 4       [2015, 10, 29, 0, 0, 32]
# ...                          ...
# 20466   [2013, 9, 13, 13, 5, 21]
# 20467  [2013, 9, 13, 16, 27, 13]
# 20468  [2014, 3, 11, 18, 16, 20]
# 20469   [2014, 4, 22, 22, 39, 4]
# 20470  [2014, 4, 22, 22, 45, 56]
#
# [20471 rows x 11 columns]

# %%
df_biodare2_clean['generalDesc'][1]
# Out:
# 'TiMet WP1.1 qRT-PCR elf3 LD | TiMet focuses on an important and general biological problem – how  are plant metabolism \nand growth regulated and orchestrated in a daily-changing environment? | WT and elf3-4 mutants, in biological duplicates, diurnal light, harvest every 2 hours\nNumbers are in transcript copy per cell, obtained assuming 1 g FW contains 25000000 cells. | The elf3 mutant was harvested at 13 day not at 21 as the rest due to its early flowering phenotype. This experiment is partenr to "TiMet WP1.1 qRT-PCR LD to LL and LD"\nGrowth conditions:\nLD 20/18C; diurn. 20.0C:18.0C 12:00:12:00 W: LD 12:00:12:00\nExperimental conditions:\nLD 20/18C; diurn. 20.0C:18.0C 12:00:12:00 W: LD 12:00:12:00'

# %% [markdown]
# #### Cleaning

# %%
#Replace None with nothing
df_biodare2_clean.replace(to_replace=[None], value="", inplace=True)
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      Controls | Global Search | null\nGrowth condit...
# 1      TiMet WP1.1 qRT-PCR elf3 LD | TiMet focuses on...
# 2      Q-PCR LD (12:12) 17C LHY | Experiment to repar...
# 3      cca1 lhy Long #1 CCA1 marker | Test for period...
# 4      cca1 lhy Long #1 CAB2 marker | Test for period...
# ...                                                  ...
# 20466  Niwa et al. (2007); GI, FKF1, CDF1, CO, FT mRN...
# 20467  AT0053:  4x3:21-LL | photoperiod alteration st...
# 20468  Analysis of Control Strains Neurospora crassa ...
# 20469  030810H3 SD-LD | Re-entrainment dynamics durin...
# 20470  SDtoLD 260410 | Re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': None, 'login': None, 'firstName': 'Fel...
# 1      [{'id': None, 'login': None, 'firstName': 'Ann...
# 2      [{'id': None, 'login': None, 'firstName': 'Aur...
# 3      [{'id': None, 'login': None, 'firstName': 'Vic...
# 4      [{'id': None, 'login': None, 'firstName': 'Vic...
# ...                                                  ...
# 20466  [{'id': None, 'login': None, 'firstName': 'Niw...
# 20467  [{'id': None, 'login': None, 'firstName': 'Adr...
# 20468  [{'id': None, 'login': None, 'firstName': 'Fel...
# 20469  [{'id': None, 'login': None, 'firstName': 'Sar...
# 20470  [{'id': None, 'login': None, 'firstName': 'Lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'Luciferase luminescence', 'equi...          False
# 1      {'technique': 'RT-PCR', 'equipment': 'PerkinEl...          False
# 2      {'technique': 'qRT-PCR', 'equipment': 'Robot +...          False
# 3      {'technique': 'Luciferase luminescence', 'equi...          False
# 4      {'technique': 'Luciferase luminescence', 'equi...          False
# ...                                                  ...            ...
# 20466  {'technique': 'RT-PCR', 'equipment': None, 'de...          False
# 20467  {'technique': 'Luciferase luminescence', 'equi...          False
# 20468  {'technique': 'Luciferase luminescence', 'equi...          False
# 20469  {'technique': 'Luciferase luminescence', 'equi...          False
# 20470  {'technique': 'Luciferase luminescence', 'equi...          False
#
#       bioDescription bioSummary               species   dataCategory  \
# 0                 []         []     Neurospora crassa    GEN_IMAGING
# 1                 []         []  Arabidopsis thaliana     TRANSCRIPT
# 2                 []         []  Arabidopsis thaliana     TRANSCRIPT
# 3                 []         []  Arabidopsis thaliana  EXPR_REPORTER
# 4                 []         []  Arabidopsis thaliana  EXPR_REPORTER
# ...              ...        ...                   ...            ...
# 20466             []         []  Arabidopsis thaliana     TRANSCRIPT
# 20467             []         []  Arabidopsis thaliana  EXPR_REPORTER
# 20468             []         []     Neurospora crassa    GEN_IMAGING
# 20469             []         []  Arabidopsis thaliana  EXPR_REPORTER
# 20470             []         []    Ostreococcus tauri    GEN_IMAGING
#
#                       provenance
# 0           [2014, 5, 5, 12, 40]
# 1      [2015, 2, 22, 18, 47, 37]
# 2         [2015, 9, 4, 1, 21, 5]
# 3      [2015, 10, 27, 20, 2, 45]
# 4       [2015, 10, 29, 0, 0, 32]
# ...                          ...
# 20466   [2013, 9, 13, 13, 5, 21]
# 20467  [2013, 9, 13, 16, 27, 13]
# 20468  [2014, 3, 11, 18, 16, 20]
# 20469   [2014, 4, 22, 22, 39, 4]
# 20470  [2014, 4, 22, 22, 45, 56]
#
# [20471 rows x 11 columns]

# %%
# Everything to lowercase

obj_cols = df_biodare2_clean.select_dtypes(include=["object", "string"]).columns
df_biodare2_clean[obj_cols] = df_biodare2_clean[obj_cols].astype("string").apply(lambda s: s.str.lower())

# %% [markdown]
# ##### Separating the columns

# %%
df_biodare2_clean["Name"] = (
    df_biodare2_clean["generalDesc"]
    .str.split('|', expand = False)
    .str[0]
    .fillna("")
)

# %%
df_biodare2_clean["Purpose"] = (
    df_biodare2_clean["generalDesc"]
    .str.split('|', expand = False)
    .str[1]
    .fillna("")
)

# %%
df_biodare2_clean["Description"] = (
    df_biodare2_clean["generalDesc"]
    .str.split('|', expand = False)
    .str[2]
    .fillna("")
)

# %%
df_biodare2_clean["Comments"] = (
    df_biodare2_clean["generalDesc"]
    .str.split('|', expand = False)
    .str[3]
    .fillna("")
)

# %%
df_biodare2_clean
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  \
# 0                 []         []     neurospora crassa    gen_imaging
# 1                 []         []  arabidopsis thaliana     transcript
# 2                 []         []  arabidopsis thaliana     transcript
# 3                 []         []  arabidopsis thaliana  expr_reporter
# 4                 []         []  arabidopsis thaliana  expr_reporter
# ...              ...        ...                   ...            ...
# 20466             []         []  arabidopsis thaliana     transcript
# 20467             []         []  arabidopsis thaliana  expr_reporter
# 20468             []         []     neurospora crassa    gen_imaging
# 20469             []         []  arabidopsis thaliana  expr_reporter
# 20470             []         []    ostreococcus tauri    gen_imaging
#
#                       provenance  \
# 0           [2014, 5, 5, 12, 40]
# 1      [2015, 2, 22, 18, 47, 37]
# 2         [2015, 9, 4, 1, 21, 5]
# 3      [2015, 10, 27, 20, 2, 45]
# 4       [2015, 10, 29, 0, 0, 32]
# ...                          ...
# 20466   [2013, 9, 13, 13, 5, 21]
# 20467  [2013, 9, 13, 16, 27, 13]
# 20468  [2014, 3, 11, 18, 16, 20]
# 20469   [2014, 4, 22, 22, 39, 4]
# 20470  [2014, 4, 22, 22, 45, 56]
#
#                                                     Name  \
# 0                                              controls
# 1                           timet wp1.1 qrt-pcr elf3 ld
# 2                              q-pcr ld (12:12) 17c lhy
# 3                          cca1 lhy long #1 cca1 marker
# 4                          cca1 lhy long #1 cab2 marker
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467                                at0053:  4x3:21-ll
# 20468     analysis of control strains neurospora crassa
# 20469                                    030810h3 sd-ld
# 20470                                     sdtold 260410
#
#                                                  Purpose  \
# 0                                         global search
# 1       timet focuses on an important and general bio...
# 2       experiment to reparameterize the clock model ...
# 3       test for period changes during seedlling grow...
# 4       test for period changes during seedlling grow...
# ...                                                  ...
# 20466   in arabidopsis thaliana, the flowering time i...
# 20467                      photoperiod alteration study
# 20468   compare different siblings of the parental/co...
# 20469   re-entrainment dynamics during transition bet...
# 20470   re-entrainment dynamics during the transition...
#
#                                              Description  \
# 0       null\ngrowth conditions:\nll24; const. 25.0c ...
# 1       wt and elf3-4 mutants, in biological duplicat...
# 2       literature data from: 'temp'\n\t    by: auror...
# 3       if periods change during development, then ou...
# 4       if periods change during development, then ou...
# ...                                                  ...
# 20466   null\ngrowth conditions:\nniwa2007; const. 22...
# 20467   luc imaging under 3:21 cycles then constant l...
# 20468   null\ngrowth conditions:\nll condition; const...
# 20469   plants entrained in 8l:16d (120umol m-2s-1) f...
# 20470   ptoc plate 0683\npcab plate0684\nlhy plate 06...
#
#                                                 Comments
# 0
# 1       the elf3 mutant was harvested at 13 day not a...
# 2       24h sample lost for several genotypes. \ncura...
# 3       data collection by victoria hibberd ca. septe...
# 4       data collection by victoria hibberd ca. septe...
# ...                                                  ...
# 20466
# 20467   imaging started 23/01/07. \nfungal infection ...
# 20468
# 20469   partner experiment : 030810h3 ld-ld\ngrowth c...
# 20470   several controls are relevant, from parallel ...
#
# [20471 rows x 15 columns]

# %% [markdown]
# #### Stats

# %%
df_biodare2_clean.columns
# Out:
# Index(['id', 'versionId', 'generalDesc', 'contributionDesc',
#        'experimentalDetails', 'characteristic', 'bioDescription', 'bioSummary',
#        'species', 'dataCategory', 'provenance', 'Name', 'Purpose',
#        'Description', 'Comments'],
#       dtype='str')

# %%
list_header_stats = ['Name','Purpose','Description','Comments']

# %% [markdown]
# #### Cleaning

# %%
for header in list_header_stats:
    df_biodare2_clean[f"{header}_clean"] = pd.Series(index=df_biodare2_clean.index, dtype="object")

# %%
df2 = df_biodare2_clean.reset_index(drop=True)

for i, row in df2.iterrows():
    print(f"Processing row {i+1}/{len(df2)}")
    for header in list_header_stats:
        value_to_clean = row[header]
        if pd.notna(value_to_clean) and value_to_clean != "":
            title = f"{header}_clean"
            df2.at[i, title]= clean_text(value_to_clean)
# Out:
# Processing row 1/20471
# Processing row 2/20471
# Processing row 3/20471
# Processing row 4/20471
# Processing row 5/20471
# Processing row 6/20471
# Processing row 7/20471
# Processing row 8/20471
# Processing row 9/20471
# Processing row 10/20471
# Processing row 11/20471
# Processing row 12/20471
# Processing row 13/20471
# Processing row 14/20471
# Processing row 15/20471
# Processing row 16/20471
# Processing row 17/20471
# Processing row 18/20471
# Processing row 19/20471
# Processing row 20/20471
# Processing row 21/20471
# Processing row 22/20471
# Processing row 23/20471
# Processing row 24/20471
# Processing row 25/20471
# Processing row 26/20471
# Processing row 27/20471
# Processing row 28/20471
# Processing row 29/20471
# Processing row 30/20471
# Processing row 31/20471
# Processing row 32/20471
# Processing row 33/20471
# Processing row 34/20471
# Processing row 35/20471
# Processing row 36/20471
# Processing row 37/20471
# Processing row 38/20471
# Processing row 39/20471
# Processing row 40/20471
# Processing row 41/20471
# Processing row 42/20471
# Processing row 43/20471
# Processing row 44/20471
# Processing row 45/20471
# Processing row 46/20471
# Processing row 47/20471
# Processing row 48/20471
# Processing row 49/20471
# Processing row 50/20471
# Processing row 51/20471
# Processing row 52/20471
# Processing row 53/20471
# Processing row 54/20471
# Processing row 55/20471
# Processing row 56/20471
# Processing row 57/20471
# Processing row 58/20471
# Processing row 59/20471
# Processing row 60/20471
# Processing row 61/20471
# Processing row 62/20471
# Processing row 63/20471
# Processing row 64/20471
# Processing row 65/20471
# Processing row 66/20471
# Processing row 67/20471
# Processing row 68/20471
# Processing row 69/20471
# Processing row 70/20471
# Processing row 71/20471
# Processing row 72/20471
# Processing row 73/20471
# Processing row 74/20471
# Processing row 75/20471
# Processing row 76/20471
# Processing row 77/20471
# Processing row 78/20471
# Processing row 79/20471
# Processing row 80/20471
# Processing row 81/20471
# Processing row 82/20471
# Processing row 83/20471
# Processing row 84/20471
# Processing row 85/20471
# Processing row 86/20471
# Processing row 87/20471
# Processing row 88/20471
# Processing row 89/20471
# Processing row 90/20471
# Processing row 91/20471
# Processing row 92/20471
# Processing row 93/20471
# Processing row 94/20471
# Processing row 95/20471
# Processing row 96/20471
# Processing row 97/20471
# Processing row 98/20471
# Processing row 99/20471
# Processing row 100/20471
# Processing row 101/20471
# Processing row 102/20471
# Processing row 103/20471
# Processing row 104/20471
# Processing row 105/20471
# Processing row 106/20471
# Processing row 107/20471
# Processing row 108/20471
# Processing row 109/20471
# Processing row 110/20471
# Processing row 111/20471
# Processing row 112/20471
# Processing row 113/20471
# Processing row 114/20471
# Processing row 115/20471
# Processing row 116/20471
# Processing row 117/20471
# Processing row 118/20471
# Processing row 119/20471
# Processing row 120/20471
# Processing row 121/20471
# Processing row 122/20471
# Processing row 123/20471
# Processing row 19975/20471
# Processing row 19976/20471
# Processing row 19977/20471
# Processing row 19978/20471
# Processing row 19979/20471
# Processing row 19980/20471
# Processing row 19981/20471
# Processing row 19982/20471
# Processing row 19983/20471
# Processing row 19984/20471
# Processing row 19985/20471
# Processing row 19986/20471
# Processing row 19987/20471
# Processing row 19988/20471
# Processing row 19989/20471
# Processing row 19990/20471
# Processing row 19991/20471
# Processing row 19992/20471
# Processing row 19993/20471
# Processing row 19994/20471
# Processing row 19995/20471
# Processing row 19996/20471
# Processing row 19997/20471
# Processing row 19998/20471
# Processing row 19999/20471
# Processing row 20000/20471
# Processing row 20001/20471
# Processing row 20002/20471
# Processing row 20003/20471
# Processing row 20004/20471
# Processing row 20005/20471
# Processing row 20006/20471
# Processing row 20007/20471
# Processing row 20008/20471
# Processing row 20009/20471
# Processing row 20010/20471
# Processing row 20011/20471
# Processing row 20012/20471
# Processing row 20013/20471
# Processing row 20014/20471
# Processing row 20015/20471
# Processing row 20016/20471
# Processing row 20017/20471
# Processing row 20018/20471
# Processing row 20019/20471
# Processing row 20020/20471
# Processing row 20021/20471
# Processing row 20022/20471
# Processing row 20023/20471
# Processing row 20024/20471
# Processing row 20025/20471
# Processing row 20026/20471
# Processing row 20027/20471
# Processing row 20028/20471
# Processing row 20029/20471
# Processing row 20030/20471
# Processing row 20031/20471
# Processing row 20032/20471
# Processing row 20033/20471
# Processing row 20034/20471
# Processing row 20035/20471
# Processing row 20036/20471
# Processing row 20037/20471
# Processing row 20038/20471
# Processing row 20039/20471
# Processing row 20040/20471
# Processing row 20041/20471
# Processing row 20042/20471
# Processing row 20043/20471
# Processing row 20044/20471
# Processing row 20045/20471
# Processing row 20046/20471
# Processing row 20047/20471
# Processing row 20048/20471
# Processing row 20049/20471
# Processing row 20050/20471
# Processing row 20051/20471
# Processing row 20052/20471
# Processing row 20053/20471
# Processing row 20054/20471
# Processing row 20055/20471
# Processing row 20056/20471
# Processing row 20057/20471
# Processing row 20058/20471
# Processing row 20059/20471
# Processing row 20060/20471
# Processing row 20061/20471
# Processing row 20062/20471
# Processing row 20063/20471
# Processing row 20064/20471
# Processing row 20065/20471
# Processing row 20066/20471
# Processing row 20067/20471
# Processing row 20068/20471
# Processing row 20069/20471
# Processing row 20070/20471
# Processing row 20071/20471
# Processing row 20072/20471
# Processing row 20073/20471
# Processing row 20074/20471
# Processing row 20075/20471
# Processing row 20076/20471
# Processing row 20077/20471
# Processing row 20078/20471
# Processing row 20079/20471
# Processing row 20080/20471
# Processing row 20081/20471
# Processing row 20082/20471
# Processing row 20083/20471
# Processing row 20084/20471
# Processing row 20085/20471
# Processing row 20086/20471
# Processing row 20087/20471
# Processing row 20088/20471
# Processing row 20089/20471
# Processing row 20090/20471
# Processing row 20091/20471
# Processing row 20092/20471
# Processing row 20093/20471
# Processing row 20094/20471
# Processing row 20095/20471
# Processing row 20096/20471
# Processing row 20097/20471
# Processing row 20098/20471
# Processing row 20099/20471
# Processing row 20100/20471
# Processing row 20101/20471
# Processing row 20102/20471
# Processing row 20103/20471
# Processing row 20104/20471
# Processing row 20105/20471
# Processing row 20106/20471
# Processing row 20107/20471
# Processing row 20108/20471
# Processing row 20109/20471
# Processing row 20110/20471
# Processing row 20111/20471
# Processing row 20112/20471
# Processing row 20113/20471
# Processing row 20114/20471
# Processing row 20115/20471
# Processing row 20116/20471
# Processing row 20117/20471
# Processing row 20118/20471
# Processing row 20119/20471
# Processing row 20120/20471
# Processing row 20121/20471
# Processing row 20122/20471
# Processing row 20123/20471
# Processing row 20124/20471
# Processing row 20125/20471
# Processing row 20126/20471
# Processing row 20127/20471
# Processing row 20128/20471
# Processing row 20129/20471
# Processing row 20130/20471
# Processing row 20131/20471
# Processing row 20132/20471
# Processing row 20133/20471
# Processing row 20134/20471
# Processing row 20135/20471
# Processing row 20136/20471
# Processing row 20137/20471
# Processing row 20138/20471
# Processing row 20139/20471
# Processing row 20140/20471
# Processing row 20141/20471
# Processing row 20142/20471
# Processing row 20143/20471
# Processing row 20144/20471
# Processing row 20145/20471
# Processing row 20146/20471
# Processing row 20147/20471
# Processing row 20148/20471
# Processing row 20149/20471
# Processing row 20150/20471
# Processing row 20151/20471
# Processing row 20152/20471
# Processing row 20153/20471
# Processing row 20154/20471
# Processing row 20155/20471
# Processing row 20156/20471
# Processing row 20157/20471
# Processing row 20158/20471
# Processing row 20159/20471
# Processing row 20160/20471
# Processing row 20161/20471
# Processing row 20162/20471
# Processing row 20163/20471
# Processing row 20164/20471
# Processing row 20165/20471
# Processing row 20166/20471
# Processing row 20167/20471
# Processing row 20168/20471
# Processing row 20169/20471
# Processing row 20170/20471
# Processing row 20171/20471
# Processing row 20172/20471
# Processing row 20173/20471
# Processing row 20174/20471
# Processing row 20175/20471
# Processing row 20176/20471
# Processing row 20177/20471
# Processing row 20178/20471
# Processing row 20179/20471
# Processing row 20180/20471
# Processing row 20181/20471
# Processing row 20182/20471
# Processing row 20183/20471
# Processing row 20184/20471
# Processing row 20185/20471
# Processing row 20186/20471
# Processing row 20187/20471
# Processing row 20188/20471
# Processing row 20189/20471
# Processing row 20190/20471
# Processing row 20191/20471
# Processing row 20192/20471
# Processing row 20193/20471
# Processing row 20194/20471
# Processing row 20195/20471
# Processing row 20196/20471
# Processing row 20197/20471
# Processing row 20198/20471
# Processing row 20199/20471
# Processing row 20200/20471
# Processing row 20201/20471
# Processing row 20202/20471
# Processing row 20203/20471
# Processing row 20204/20471
# Processing row 20205/20471
# Processing row 20206/20471
# Processing row 20207/20471
# Processing row 20208/20471
# Processing row 20209/20471
# Processing row 20210/20471
# Processing row 20211/20471
# Processing row 20212/20471
# Processing row 20213/20471
# Processing row 20214/20471
# Processing row 20215/20471
# Processing row 20216/20471
# Processing row 20217/20471
# Processing row 20218/20471
# Processing row 20219/20471
# Processing row 20220/20471
# Processing row 20221/20471
# Processing row 20222/20471
# Processing row 20223/20471
# Processing row 20224/20471
# Processing row 20225/20471
# Processing row 20226/20471
# Processing row 20227/20471
# Processing row 20228/20471
# Processing row 20229/20471
# Processing row 20230/20471
# Processing row 20231/20471
# Processing row 20232/20471
# Processing row 20233/20471
# Processing row 20234/20471
# Processing row 20235/20471
# Processing row 20236/20471
# Processing row 20237/20471
# Processing row 20238/20471
# Processing row 20239/20471
# Processing row 20240/20471
# Processing row 20241/20471
# Processing row 20242/20471
# Processing row 20243/20471
# Processing row 20244/20471
# Processing row 20245/20471
# Processing row 20246/20471
# Processing row 20247/20471
# Processing row 20248/20471
# Processing row 20249/20471
# Processing row 20250/20471
# Processing row 20251/20471
# Processing row 20252/20471
# Processing row 20253/20471
# Processing row 20254/20471
# Processing row 20255/20471
# Processing row 20256/20471
# Processing row 20257/20471
# Processing row 20258/20471
# Processing row 20259/20471
# Processing row 20260/20471
# Processing row 20261/20471
# Processing row 20262/20471
# Processing row 20263/20471
# Processing row 20264/20471
# Processing row 20265/20471
# Processing row 20266/20471
# Processing row 20267/20471
# Processing row 20268/20471
# Processing row 20269/20471
# Processing row 20270/20471
# Processing row 20271/20471
# Processing row 20272/20471
# Processing row 20273/20471
# Processing row 20274/20471
# Processing row 20275/20471
# Processing row 20276/20471
# Processing row 20277/20471
# Processing row 20278/20471
# Processing row 20279/20471
# Processing row 20280/20471
# Processing row 20281/20471
# Processing row 20282/20471
# Processing row 20283/20471
# Processing row 20284/20471
# Processing row 20285/20471
# Processing row 20286/20471
# Processing row 20287/20471
# Processing row 20288/20471
# Processing row 20289/20471
# Processing row 20290/20471
# Processing row 20291/20471
# Processing row 20292/20471
# Processing row 20293/20471
# Processing row 20294/20471
# Processing row 20295/20471
# Processing row 20296/20471
# Processing row 20297/20471
# Processing row 20298/20471
# Processing row 20299/20471
# Processing row 20300/20471
# Processing row 20301/20471
# Processing row 20302/20471
# Processing row 20303/20471
# Processing row 20304/20471
# Processing row 20305/20471
# Processing row 20306/20471
# Processing row 20307/20471
# Processing row 20308/20471
# Processing row 20309/20471
# Processing row 20310/20471
# Processing row 20311/20471
# Processing row 20312/20471
# Processing row 20313/20471
# Processing row 20314/20471
# Processing row 20315/20471
# Processing row 20316/20471
# Processing row 20317/20471
# Processing row 20318/20471
# Processing row 20319/20471
# Processing row 20320/20471
# Processing row 20321/20471
# Processing row 20322/20471
# Processing row 20323/20471
# Processing row 20324/20471
# Processing row 20325/20471
# Processing row 20326/20471
# Processing row 20327/20471
# Processing row 20328/20471
# Processing row 20329/20471
# Processing row 20330/20471
# Processing row 20331/20471
# Processing row 20332/20471
# Processing row 20333/20471
# Processing row 20334/20471
# Processing row 20335/20471
# Processing row 20336/20471
# Processing row 20337/20471
# Processing row 20338/20471
# Processing row 20339/20471
# Processing row 20340/20471
# Processing row 20341/20471
# Processing row 20342/20471
# Processing row 20343/20471
# Processing row 20344/20471
# Processing row 20345/20471
# Processing row 20346/20471
# Processing row 20347/20471
# Processing row 20348/20471
# Processing row 20349/20471
# Processing row 20350/20471
# Processing row 20351/20471
# Processing row 20352/20471
# Processing row 20353/20471
# Processing row 20354/20471
# Processing row 20355/20471
# Processing row 20356/20471
# Processing row 20357/20471
# Processing row 20358/20471
# Processing row 20359/20471
# Processing row 20360/20471
# Processing row 20361/20471
# Processing row 20362/20471
# Processing row 20363/20471
# Processing row 20364/20471
# Processing row 20365/20471
# Processing row 20366/20471
# Processing row 20367/20471
# Processing row 20368/20471
# Processing row 20369/20471
# Processing row 20370/20471
# Processing row 20371/20471
# Processing row 20372/20471
# Processing row 20373/20471
# Processing row 20374/20471
# Processing row 20375/20471
# Processing row 20376/20471
# Processing row 20377/20471
# Processing row 20378/20471
# Processing row 20379/20471
# Processing row 20380/20471
# Processing row 20381/20471
# Processing row 20382/20471
# Processing row 20383/20471
# Processing row 20384/20471
# Processing row 20385/20471
# Processing row 20386/20471
# Processing row 20387/20471
# Processing row 20388/20471
# Processing row 20389/20471
# Processing row 20390/20471
# Processing row 20391/20471
# Processing row 20392/20471
# Processing row 20393/20471
# Processing row 20394/20471
# Processing row 20395/20471
# Processing row 20396/20471
# Processing row 20397/20471
# Processing row 20398/20471
# Processing row 20399/20471
# Processing row 20400/20471
# Processing row 20401/20471
# Processing row 20402/20471
# Processing row 20403/20471
# Processing row 20404/20471
# Processing row 20405/20471
# Processing row 20406/20471
# Processing row 20407/20471
# Processing row 20408/20471
# Processing row 20409/20471
# Processing row 20410/20471
# Processing row 20411/20471
# Processing row 20412/20471
# Processing row 20413/20471
# Processing row 20414/20471
# Processing row 20415/20471
# Processing row 20416/20471
# Processing row 20417/20471
# Processing row 20418/20471
# Processing row 20419/20471
# Processing row 20420/20471
# Processing row 20421/20471
# Processing row 20422/20471
# Processing row 20423/20471
# Processing row 20424/20471
# Processing row 20425/20471
# Processing row 20426/20471
# Processing row 20427/20471
# Processing row 20428/20471
# Processing row 20429/20471
# Processing row 20430/20471
# Processing row 20431/20471
# Processing row 20432/20471
# Processing row 20433/20471
# Processing row 20434/20471
# Processing row 20435/20471
# Processing row 20436/20471
# Processing row 20437/20471
# Processing row 20438/20471
# Processing row 20439/20471
# Processing row 20440/20471
# Processing row 20441/20471
# Processing row 20442/20471
# Processing row 20443/20471
# Processing row 20444/20471
# Processing row 20445/20471
# Processing row 20446/20471
# Processing row 20447/20471
# Processing row 20448/20471
# Processing row 20449/20471
# Processing row 20450/20471
# Processing row 20451/20471
# Processing row 20452/20471
# Processing row 20453/20471
# Processing row 20454/20471
# Processing row 20455/20471
# Processing row 20456/20471
# Processing row 20457/20471
# Processing row 20458/20471
# Processing row 20459/20471
# Processing row 20460/20471
# Processing row 20461/20471
# Processing row 20462/20471
# Processing row 20463/20471
# Processing row 20464/20471
# Processing row 20465/20471
# Processing row 20466/20471
# Processing row 20467/20471
# Processing row 20468/20471
# Processing row 20469/20471
# Processing row 20470/20471
# Processing row 20471/20471

# %%
df_biodare2_clean = df2

# %%
# Words count
for idx, row in df_biodare2_clean.iterrows():
    for header in list_header_stats: 
        str_to_count = df_biodare2_clean.at[idx, header]
        count_number = count_words(str_to_count)
        title = f"{header}_words_count"

        df_biodare2_clean.at[idx, title] = count_number

# %%
df_biodare2_clean
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#                                              Description  \
# 0       null\ngrowth conditions:\nll24; const. 25.0c ...
# 1       wt and elf3-4 mutants, in biological duplicat...
# 2       literature data from: 'temp'\n\t    by: auror...
# 3       if periods change during development, then ou...
# 4       if periods change during development, then ou...
# ...                                                  ...
# 20466   null\ngrowth conditions:\nniwa2007; const. 22...
# 20467   luc imaging under 3:21 cycles then constant l...
# 20468   null\ngrowth conditions:\nll condition; const...
# 20469   plants entrained in 8l:16d (120umol m-2s-1) f...
# 20470   ptoc plate 0683\npcab plate0684\nlhy plate 06...
#
#                                                 Comments  \
# 0
# 1       the elf3 mutant was harvested at 13 day not a...
# 2       24h sample lost for several genotypes. \ncura...
# 3       data collection by victoria hibberd ca. septe...
# 4       data collection by victoria hibberd ca. septe...
# ...                                                  ...
# 20466
# 20467   imaging started 23/01/07. \nfungal infection ...
# 20468
# 20469   partner experiment : 030810h3 ld-ld\ngrowth c...
# 20470   several controls are relevant, from parallel ...
#
#                                              Name_clean  \
# 0                                            [controls]
# 1                                           [timet, ld]
# 2                                             [ld, lhy]
# 3                                   [lhy, long, marker]
# 4                                   [lhy, long, marker]
# ...                                                 ...
# 20466              [niwa, et, al, gi, co, ft, mrna, wt]
# 20467                                                []
# 20468  [analysis, control, strains, neurospora, crassa]
# 20469                                                []
# 20470                                          [sdtold]
#
#                                            Purpose_clean  \
# 0                                       [global, search]
# 1      [timet, focuses, important, general, biologica...
# 2      [experiment, reparameterize, clock, model, wit...
# 3      [test, period, changes, seedlling, growth, top...
# 4      [test, period, changes, seedlling, growth, top...
# ...                                                  ...
# 20466  [arabidopsis, thaliana, flowering, time, regul...
# 20467                   [photoperiod, alteration, study]
# 20468  [compare, different, siblings, parentalcontrol...
# 20469  [dynamics, transition, lightdark, cycles, diff...
# 20470  [dynamics, transition, lightdark, cycles, diff...
#
#                                        Description_clean  \
# 0      [null, growth, conditions, const, w, experimen...
# 1      [wt, mutants, biological, duplicates, diurnal,...
# 2      [literature, data, temp, aurora, seedlings, en...
# 3      [periods, change, development, genetic, screen...
# 4      [periods, change, development, genetic, screen...
# ...                                                  ...
# 20466  [null, growth, conditions, const, w, ld, exper...
# 20467  [luc, imaging, cycles, constant, light, replic...
# 20468  [null, growth, conditions, condition, const, w...
# 20469  [plants, entrained, days, experimental, condit...
# 20470  [ptoc, plate, pcab, lhy, plate, control, plate...
#
#                                           Comments_clean Name_words_count  \
# 0                                                    NaN              1.0
# 1      [mutant, harvested, day, rest, due, early, flo...              5.0
# 2      [sample, lost, several, genotypes, curated, an...              5.0
# 3      [data, collection, victoria, hibberd, ca, sept...              6.0
# 4      [data, collection, victoria, hibberd, ca, sept...              6.0
# ...                                                  ...              ...
# 20466                                                NaN             14.0
# 20467  [imaging, started, fungal, infection, gi, lhy,...              2.0
# 20468                                                NaN              6.0
# 20469  [partner, experiment, growth, conditions, cons...              2.0
# 20470  [several, controls, relevant, parallel, experi...              2.0
#
#       Purpose_words_count Description_words_count  Comments_words_count
# 0                     2.0                    16.0                   0.0
# 1                    23.0                    28.0                  53.0
# 2                     9.0                    43.0                  75.0
# 3                    17.0                    73.0                  37.0
# 4                    17.0                    73.0                  37.0
# ...                   ...                     ...                   ...
# 20466               244.0                    17.0                   0.0
# 20467                 3.0                    16.0                  64.0
# 20468                20.0                    17.0                   0.0
# 20469                24.0                    22.0                  25.0
# 20470                53.0                    16.0                 146.0
#
# [20471 rows x 23 columns]

# %%
test = df2.at[0,"Purpose_clean"]
len(test)
# Out:
# 2

# %%
list_header_stats = ['Name_clean','Purpose_clean','Description_clean','Comments_clean']

# %%
for header in list_header_stats:
    df_biodare2_clean[f"{header}_word_count"] = pd.Series(index=df_biodare2_clean.index, dtype="object")

# %%
df_biodare2_clean["Name_clean_word_count"] = (
    df_biodare2_clean["Name_clean"].apply(lambda x: len(x) if isinstance(x, list) else 0)
)

# %%
df_biodare2_clean["Purpose_clean_word_count"] = (
    df_biodare2_clean["Purpose_clean"].apply(lambda x: len(x) if isinstance(x, list) else 0)
)

# %%
df_biodare2_clean["Description_clean_word_count"] = (
    df_biodare2_clean["Description_clean"].apply(lambda x: len(x) if isinstance(x, list) else 0)
)

# %%
df_biodare2_clean["Comments_clean_word_count"] = (
    df_biodare2_clean["Comments_clean"].apply(lambda x: len(x) if isinstance(x, list) else 0)
)

# %%
df_biodare2_clean.at[2,"Name_clean"]
# Out:
# ['ld', 'lhy']

# %%
df_biodare2_clean
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#                                        Description_clean  \
# 0      [null, growth, conditions, const, w, experimen...
# 1      [wt, mutants, biological, duplicates, diurnal,...
# 2      [literature, data, temp, aurora, seedlings, en...
# 3      [periods, change, development, genetic, screen...
# 4      [periods, change, development, genetic, screen...
# ...                                                  ...
# 20466  [null, growth, conditions, const, w, ld, exper...
# 20467  [luc, imaging, cycles, constant, light, replic...
# 20468  [null, growth, conditions, condition, const, w...
# 20469  [plants, entrained, days, experimental, condit...
# 20470  [ptoc, plate, pcab, lhy, plate, control, plate...
#
#                                           Comments_clean Name_words_count  \
# 0                                                    NaN              1.0
# 1      [mutant, harvested, day, rest, due, early, flo...              5.0
# 2      [sample, lost, several, genotypes, curated, an...              5.0
# 3      [data, collection, victoria, hibberd, ca, sept...              6.0
# 4      [data, collection, victoria, hibberd, ca, sept...              6.0
# ...                                                  ...              ...
# 20466                                                NaN             14.0
# 20467  [imaging, started, fungal, infection, gi, lhy,...              2.0
# 20468                                                NaN              6.0
# 20469  [partner, experiment, growth, conditions, cons...              2.0
# 20470  [several, controls, relevant, parallel, experi...              2.0
#
#       Purpose_words_count Description_words_count Comments_words_count  \
# 0                     2.0                    16.0                  0.0
# 1                    23.0                    28.0                 53.0
# 2                     9.0                    43.0                 75.0
# 3                    17.0                    73.0                 37.0
# 4                    17.0                    73.0                 37.0
# ...                   ...                     ...                  ...
# 20466               244.0                    17.0                  0.0
# 20467                 3.0                    16.0                 64.0
# 20468                20.0                    17.0                  0.0
# 20469                24.0                    22.0                 25.0
# 20470                53.0                    16.0                146.0
#
#       Name_clean_word_count Purpose_clean_word_count  \
# 0                         1                        2
# 1                         2                       12
# 2                         2                        7
# 3                         3                       11
# 4                         3                       11
# ...                     ...                      ...
# 20466                     8                      130
# 20467                     0                        3
# 20468                     5                       13
# 20469                     0                       15
# 20470                     1                       31
#
#       Description_clean_word_count  Comments_clean_word_count
# 0                               12                          0
# 1                               20                         25
# 2                               17                         45
# 3                               42                         24
# 4                               42                         24
# ...                            ...                        ...
# 20466                           11                          0
# 20467                            8                         38
# 20468                           13                          0
# 20469                           10                         13
# 20470                           10                         76
#
# [20471 rows x 27 columns]

# %%
# Creating the empty columns for lemma text and entities 
for header in list_header_stats:
    df_biodare2_clean[f"{header}_lemmatize"] = pd.Series(index=df_biodare2_clean.index, dtype="object")
    df_biodare2_clean[f"{header}_entities"]  = pd.Series(index=df_biodare2_clean.index, dtype="object")

# %%
df_biodare2_clean
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#       Description_clean_word_count Comments_clean_word_count  \
# 0                               12                         0
# 1                               20                        25
# 2                               17                        45
# 3                               42                        24
# 4                               42                        24
# ...                            ...                       ...
# 20466                           11                         0
# 20467                            8                        38
# 20468                           13                         0
# 20469                           10                        13
# 20470                           10                        76
#
#       Name_clean_lemmatize Name_clean_entities Purpose_clean_lemmatize  \
# 0                      NaN                 NaN                     NaN
# 1                      NaN                 NaN                     NaN
# 2                      NaN                 NaN                     NaN
# 3                      NaN                 NaN                     NaN
# 4                      NaN                 NaN                     NaN
# ...                    ...                 ...                     ...
# 20466                  NaN                 NaN                     NaN
# 20467                  NaN                 NaN                     NaN
# 20468                  NaN                 NaN                     NaN
# 20469                  NaN                 NaN                     NaN
# 20470                  NaN                 NaN                     NaN
#
#       Purpose_clean_entities Description_clean_lemmatize  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ...                      ...                         ...
# 20466                    NaN                         NaN
# 20467                    NaN                         NaN
# 20468                    NaN                         NaN
# 20469                    NaN                         NaN
# 20470                    NaN                         NaN
#
#       Description_clean_entities Comments_clean_lemmatize  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 20466                        NaN                      NaN
# 20467                        NaN                      NaN
# 20468                        NaN                      NaN
# 20469                        NaN                      NaN
# 20470                        NaN                      NaN
#
#        Comments_clean_entities
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 20466                      NaN
# 20467                      NaN
# 20468                      NaN
# 20469                      NaN
# 20470                      NaN
#
# [20471 rows x 35 columns]

# %%
# Lemmatisation and entity recognition
for idx, row in df_biodare2_clean.iterrows():
    for header in list_header_stats: 
        
        text = df_biodare2_clean.at[idx, header]
        join_text = to_text(text)
        
        lemma_str = lemmatizer("" if pd.isna(join_text) else str(join_text))
        title_lemma = f"{header}_lemmatize"
        df_biodare2_clean.at[idx, title_lemma] = lemma_str

        entities = entities_recognition(lemma_str)
        title_entities = f"{header}_entities"
        df_biodare2_clean.at[idx, title_entities] = entities

# %%
df_biodare2_clean
# Out:
#                    id versionId  \
# 0                1153     2.0.2
# 1                2842     2.0.2
# 2                3492     3.0.3
# 3                3638     4.0.3
# 4                3647     2.0.2
# ...               ...       ...
# 20466  13790739219191     2.0.3
# 20467  13790860334747     2.0.3
# 20468  13945617808900     5.0.4
# 20469  13982027442235     4.0.5
# 20470  13982031569136     4.0.3
#
#                                              generalDesc  \
# 0      controls | global search | null\ngrowth condit...
# 1      timet wp1.1 qrt-pcr elf3 ld | timet focuses on...
# 2      q-pcr ld (12:12) 17c lhy | experiment to repar...
# 3      cca1 lhy long #1 cca1 marker | test for period...
# 4      cca1 lhy long #1 cab2 marker | test for period...
# ...                                                  ...
# 20466  niwa et al. (2007); gi, fkf1, cdf1, co, ft mrn...
# 20467  at0053:  4x3:21-ll | photoperiod alteration st...
# 20468  analysis of control strains neurospora crassa ...
# 20469  030810h3 sd-ld | re-entrainment dynamics durin...
# 20470  sdtold 260410 | re-entrainment dynamics during...
#
#                                         contributionDesc  \
# 0      [{'id': none, 'login': none, 'firstname': 'fel...
# 1      [{'id': none, 'login': none, 'firstname': 'ann...
# 2      [{'id': none, 'login': none, 'firstname': 'aur...
# 3      [{'id': none, 'login': none, 'firstname': 'vic...
# 4      [{'id': none, 'login': none, 'firstname': 'vic...
# ...                                                  ...
# 20466  [{'id': none, 'login': none, 'firstname': 'niw...
# 20467  [{'id': none, 'login': none, 'firstname': 'adr...
# 20468  [{'id': none, 'login': none, 'firstname': 'fel...
# 20469  [{'id': none, 'login': none, 'firstname': 'sar...
# 20470  [{'id': none, 'login': none, 'firstname': 'lau...
#
#                                      experimentalDetails characteristic  \
# 0      {'technique': 'luciferase luminescence', 'equi...          false
# 1      {'technique': 'rt-pcr', 'equipment': 'perkinel...          false
# 2      {'technique': 'qrt-pcr', 'equipment': 'robot +...          false
# 3      {'technique': 'luciferase luminescence', 'equi...          false
# 4      {'technique': 'luciferase luminescence', 'equi...          false
# ...                                                  ...            ...
# 20466  {'technique': 'rt-pcr', 'equipment': none, 'de...          false
# 20467  {'technique': 'luciferase luminescence', 'equi...          false
# 20468  {'technique': 'luciferase luminescence', 'equi...          false
# 20469  {'technique': 'luciferase luminescence', 'equi...          false
# 20470  {'technique': 'luciferase luminescence', 'equi...          false
#
#       bioDescription bioSummary               species   dataCategory  ...  \
# 0                 []         []     neurospora crassa    gen_imaging  ...
# 1                 []         []  arabidopsis thaliana     transcript  ...
# 2                 []         []  arabidopsis thaliana     transcript  ...
# 3                 []         []  arabidopsis thaliana  expr_reporter  ...
# 4                 []         []  arabidopsis thaliana  expr_reporter  ...
# ...              ...        ...                   ...            ...  ...
# 20466             []         []  arabidopsis thaliana     transcript  ...
# 20467             []         []  arabidopsis thaliana  expr_reporter  ...
# 20468             []         []     neurospora crassa    gen_imaging  ...
# 20469             []         []  arabidopsis thaliana  expr_reporter  ...
# 20470             []         []    ostreococcus tauri    gen_imaging  ...
#
#       Description_clean_word_count Comments_clean_word_count  \
# 0                               12                         0
# 1                               20                        25
# 2                               17                        45
# 3                               42                        24
# 4                               42                        24
# ...                            ...                       ...
# 20466                           11                         0
# 20467                            8                        38
# 20468                           13                         0
# 20469                           10                        13
# 20470                           10                        76
#
#                             Name_clean_lemmatize    Name_clean_entities  \
# 0                                        control            [(control)]
# 1                                       timet ld                     []
# 2                                         ld lhy            [(ld, lhy)]
# 3                                lhy long marker  [(lhy, long, marker)]
# 4                                lhy long marker  [(lhy, long, marker)]
# ...                                          ...                    ...
# 20466                niwa et al gi co ft mrna wt       [(niwa), (mrna)]
# 20467                                                                []
# 20468  analysis control strain neurospora crassa           [(analysis)]
# 20469                                                                []
# 20470                                     sdtold             [(sdtold)]
#
#                                  Purpose_clean_lemmatize  \
# 0                                          global search
# 1      timet focus important general biological probl...
# 2      experiment reparameterize clock model without ...
# 3      test period change seedlle growth topcount wt ...
# 4      test period change seedlle growth topcount wt ...
# ...                                                  ...
# 20466  arabidopsis thaliana flower time regulate circ...
# 20467                       photoperiod alteration study
# 20468  compare different sibling parentalcontrol stra...
# 20469  dynamic transition lightdark cycle different p...
# 20470  dynamic transition lightdark cycle different p...
#
#                                   Purpose_clean_entities  \
# 0                                             [(global)]
# 1      [(biological), (plant, metabolism), (growth, r...
# 2      [(experiment), (clock, model), (exogenous), (s...
# 3                                    [(seedlle, growth)]
# 4                                    [(seedlle, growth)]
# ...                                                  ...
# 20466  [(arabidopsis, thaliana), (flower), (circadian...
# 20467                                    [(photoperiod)]
# 20468  [(compare), (sibling), (parentalcontrol), (cir...
# 20469  [(dynamic, transition, lightdark, cycle), (pho...
# 20470  [(dynamic, transition, lightdark, cycle), (pho...
#
#                              Description_clean_lemmatize  \
# 0      null growth condition const w experimental con...
# 1      wt mutant biological duplicate diurnal light h...
# 2      literature datum temp aurora seedling entrain ...
# 3      period change development genetic screen clock...
# 4      period change development genetic screen clock...
# ...                                                  ...
# 20466  null growth condition const w ld experimental ...
# 20467  luc image cycle constant light replicate exper...
# 20468  null growth condition condition const w experi...
# 20469  plant entrain day experimental condition day d...
# 20470  ptoc plate pcab lhy plate control plate toc pl...
#
#                               Description_clean_entities  \
# 0      [(null, growth, condition), (experimental, con...
# 1      [(mutant), (biological), (diurnal, light, harv...
# 2      [(literature, datum), (seedling), (day), (whit...
# 3      [(development), (genetic, screen), (clock, mut...
# 4      [(development), (genetic, screen), (clock, mut...
# ...                                                  ...
# 20466  [(null, growth, condition), (experimental, con...
# 20467                                     [(experiment)]
# 20468  [(null, growth, condition), (condition), (expe...
# 20469  [(plant), (experimental, condition), (day), (d...
# 20470                     [(ptoc, plate), (plhy, plate)]
#
#                                 Comments_clean_lemmatize  \
# 0
# 1      mutant harvest day rest due early flowering ph...
# 2      sample lose several genotype curate andrew mil...
# 3      datum collection victoria hibberd can septembe...
# 4      datum collection victoria hibberd can septembe...
# ...                                                  ...
# 20466
# 20467  image start fungal infection gi lhy mutant pla...
# 20468
# 20469  partner experiment growth condition const w ld...
# 20470  several control relevant parallel experiment a...
#
#                                  Comments_clean_entities
# 0                                                     []
# 1      [(mutant), (day), (flowering), (phenotype), (e...
# 2      [(sample, lose), (genotype), (millar), (manual...
# 3      [(datum, collection, victoria), (hibberd), (mi...
# 4      [(datum, collection, victoria), (hibberd), (mi...
# ...                                                  ...
# 20466                                                 []
# 20467  [(image), (fungal, infection), (lhy, group), (...
# 20468                                                 []
# 20469  [(experiment), (growth, condition), (experimen...
# 20470  [(control), (culture, plate), (marker), (marke...
#
# [20471 rows x 35 columns]

# %% [markdown]
# #### Saving the dataset for future work

# %%
os.getcwd()
# Out:
# '/home/eidf128/eidf128/shared/export/juliana/export/juliana/BioDare_metadata_20250722'

# %%
cd ..
# Out:
# /home/eidf128/eidf128/shared/export/juliana/export/juliana

# %%
df_biodare2_clean.to_csv("df_biodare2_clean_20260312.csv", index = False)
